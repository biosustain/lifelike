# %% [markdown]
# # Init

# %%
# %load_ext autoreload

# %%
from llmlib.app import app
context = app.app_context()
context.push()

# %% [markdown]
# ## Imports

# %%
from develop.utils import formatters

# %% [markdown]
# ## Inputs

# %%
query="What is the relationship between Zn2+ and glycolate?"

# %% [markdown]
# ## Utils

# %%
import openai

def chatGPTQA(query: str):
    return openai.ChatCompletion.create(
        messages=[
            { "role": "user", "content": query }
        ],
        model="gpt-3.5-turbo",
        temperature=0
    )

# %% [markdown]
# ## Initial check
#
# Current response:

# %%
chatGPTQA(query)
# Out:
# <OpenAIObject chat.completion id=chatcmpl-8Da1yVZMYXL6jKEcKCIo2K53NV1Oc at 0x7f593f676db0> JSON: {
#   "id": "chatcmpl-8Da1yVZMYXL6jKEcKCIo2K53NV1Oc",
#   "object": "chat.completion",
#   "created": 1698247458,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "The relationship between Zn2+ and glycolate is that Zn2+ can form a complex with glycolate. In this complex, the Zn2+ ion binds to the oxygen atoms in the glycolate molecule, forming coordination bonds. This interaction between Zn2+ and glycolate allows for the stabilization and transport of glycolate in biological systems."
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 21,
#     "completion_tokens": 77,
#     "total_tokens": 98
#   }
# }

# %% [markdown]
# # Compose chain

# %% [markdown]
# ## Init llm model

# %%
from langchain.chat_models import ChatOpenAI
llm = ChatOpenAI(temperature=0, verbose=True)
llm
# Out:
# ChatOpenAI(cache=None, verbose=True, callbacks=None, callback_manager=None, tags=None, metadata=None, client=<class 'openai.api_resources.chat_completion.ChatCompletion'>, model_name='gpt-3.5-turbo', temperature=0.0, model_kwargs={}, openai_api_key='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', openai_api_base='', openai_organization='', openai_proxy='', request_timeout=None, max_retries=6, streaming=False, n=1, max_tokens=None, tiktoken_model_name=None)

# %% [markdown]
# ## Pepare prompts for core term extraction

# %%
from langchain.prompts import PromptTemplate
from langchain.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
)
QUERY_KEY = 'query'

core_terms_prompt_template = ChatPromptTemplate.from_messages([
    SystemMessagePromptTemplate(
        prompt=PromptTemplate(
            template="Always response with comma separated list of chemical or biological terms identified in prompt.",
            input_variables=[]
        )
    ),
    HumanMessagePromptTemplate(
        prompt=PromptTemplate(
            template=f"{{{QUERY_KEY}}}",
            input_variables=[QUERY_KEY],
        )
    )
])
core_terms_prompt_template
# Out:
# ChatPromptTemplate(input_variables=['query'], output_parser=None, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], output_parser=None, partial_variables={}, template='Always response with comma separated list of chemical or biological terms identified in prompt.', template_format='f-string', validate_template=True), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['query'], output_parser=None, partial_variables={}, template='{query}', template_format='f-string', validate_template=True), additional_kwargs={})])

# %% [markdown]
# ## Define embedding model

# %%
from langchain.embeddings import OpenAIEmbeddings
embeddings = OpenAIEmbeddings()
embeddings
# Out:
# OpenAIEmbeddings(client=<class 'openai.api_resources.embedding.Embedding'>, model='text-embedding-ada-002', deployment='text-embedding-ada-002', openai_api_version='', openai_api_base='', openai_api_type='', openai_proxy='', embedding_ctx_length=8191, openai_api_key='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', openai_organization='', allowed_special=set(), disallowed_special='all', chunk_size=1000, max_retries=6, request_timeout=None, headers=None, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False)

# %% [markdown]
# ## Define vectorstore

# %%
from langchain.vectorstores import Chroma

# %%
# Vectorstore
vectorstore = Chroma(embedding_function=embeddings, persist_directory="./chroma_db_oai")
vectorstore

# %% [markdown]
# ## Get graph reference

# %% [markdown]
# ### Define neo4j connector

# %%
from llmlib.database import Neo4j

# %%
graph = Neo4j().graph()
graph.schema = ''  # Overwrite schema to avoid it to be loaded from db (lengthy process not ussed in here)

# %% [markdown]
# #### Init graph search API wrapper

# %%
from llmlib.utils.search.cypher_search_api_wrapper import CypherSearchAPIWrapper

# %%
search = CypherSearchAPIWrapper(
    graph=graph,
    verbose=True,
    return_intermediate_steps=True
)
search
# Out:
# CypherSearchAPIWrapper(graph=<llmlib.utils.lazy_neo4j_graph.LazyNeo4jGraph object at 0x7f593ddfabd0>, related_nodes_query='\nUNWIND $terms AS term\nMATCH (s:Synonym {lowercase_name: toLower(term)})<-[:HAS_SYNONYM]-(n)\nWHERE n.eid IS NOT NULL AND NOT n.eid IN $exclude_eids\nWITH apoc.text.levenshteinSimilarity(term, n.name) as similarity, s, n, term\nORDER BY similarity DESC\nWHERE similarity > 0.5\nWITH DISTINCT term, collect({node: n, node_id: id(n), similarity: similarity})[0..$top_k_matches] as matches\nRETURN term, matches\n', related_nodes_query_params={'top_k_matches': 10, 'exclude_eids': ['NAD-P-OR-NOP', 'NADH-P-OR-NOP', 'Donor-H2', 'Acceptor', 'HYDROGEN-PEROXIDE', 'OXYGEN-MOLECULE', 'NAD', 'NADP', 'NADH', 'NADPH', 'WATER', 'CARBON-DIOXIDE', 'FAD', 'CO-A', 'UDP', 'AMMONIA', 'NA+', 'AMMONIUM', 'PROTON', 'CARBON-MONOXIDE', 'GTP', 'ADP', 'GDP', 'AMP', 'ATP', '3-5-ADP', 'PPI', 'Pi']}, relationships_query="\nUNWIND apoc.coll.combinations($term_match, 2) AS termPair\nUNWIND termPair[0]['matches'] as matchA\nUNWIND termPair[1]['matches'] as matchB\nWITH matchA, matchB, matchA['similarity'] * matchB['similarity'] AS similarity\nORDER BY similarity DESC\nWHERE similarity > 0.5\nMATCH (a), (b)\nWHERE id(a) = matchA['id'] AND id(b) = matchB['id']\nMATCH path=allShortestPaths((a)-[*1..]-(b))\nWHERE\n all(r in relationships(path) where type(r) in $include_rels)\n and all(n in nodes(path) where not n.eid in $exclude_eids)\nRETURN path LIMIT $top_k\n", relationships_query_params={'top_k': 5, 'include_rels': ['CONSUMED_BY', 'PRODUCES', 'CATALYZES', 'REGULATES', 'HAS_TXONOMY', 'IS', 'HAS_KO', 'ELEMENT_OF', 'ENCODES'], 'exclude_eids': ['NAD-P-OR-NOP', 'NADH-P-OR-NOP', 'Donor-H2', 'Acceptor', 'HYDROGEN-PEROXIDE', 'OXYGEN-MOLECULE', 'NAD', 'NADP', 'NADH', 'NADPH', 'WATER', 'CARBON-DIOXIDE', 'FAD', 'CO-A', 'UDP', 'AMMONIA', 'NA+', 'AMMONIUM', 'PROTON', 'CARBON-MONOXIDE', 'GTP', 'ADP', 'GDP', 'AMP', 'ATP', '3-5-ADP', 'PPI', 'Pi']})

# %% [markdown]
# ## Compose QA chain with graph retriever

# %% [markdown]
# ### Init graph retriever

# %%
from llmlib.utils.retrievers.graph_search_retriever import GraphSearchRetriever

# %%
retriever = GraphSearchRetriever.from_llm(
    vectorstore=vectorstore,
    llm=llm,
    graph_search=search,
    prompt=core_terms_prompt_template,
    verbose=True,
    return_intermediate_steps=True
)
retriever
# Out:
# GraphSearchRetriever(tags=None, metadata=None, vectorstore=<langchain.vectorstores.chroma.Chroma object at 0x7f593f7b7c50>, llm_chain=LLMChain(memory=None, callbacks=None, callback_manager=None, verbose=False, tags=None, metadata=None, prompt=ChatPromptTemplate(input_variables=['query'], output_parser=None, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], output_parser=None, partial_variables={}, template='Always response with comma separated list of chemical or biological terms identified in prompt.', template_format='f-string', validate_template=True), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['query'], output_parser=None, partial_variables={}, template='{query}', template_format='f-string', validate_template=True), additional_kwargs={})]), llm=ChatOpenAI(cache=None, verbose=True, callbacks=None, callback_manager=None, tags=None, metadata=None, client=<class 'openai.api_resources.chat_completion.ChatCompletion'>, model_name='gpt-3.5-turbo', temperature=0.0, model_kwargs={}, openai_api_key='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', openai_api_base='', openai_organization='', openai_proxy='', request_timeout=None, max_retries=6, streaming=False, n=1, max_tokens=None, tiktoken_model_name=None), output_key='text', output_parser=CommaSeparatedListOutputParser(), return_final_only=True, llm_kwargs={}), graph_search=CypherSearchAPIWrapper(graph=<llmlib.utils.lazy_neo4j_graph.LazyNeo4jGraph object at 0x7f593ddfabd0>, related_nodes_query='\nUNWIND $terms AS term\nMATCH (s:Synonym {lowercase_name: toLower(term)})<-[:HAS_SYNONYM]-(n)\nWHERE n.eid IS NOT NULL AND NOT n.eid IN $exclude_eids\nWITH apoc.text.levenshteinSimilarity(term, n.name) as similarity, s, n, term\nORDER BY similarity DESC\nWHERE similarity > 0.5\nWITH DISTINCT term, collect({node: n, node_id: id(n), similarity: similarity})[0..$top_k_matches] as matches\nRETURN term, matches\n', related_nodes_query_params={'top_k_matches': 10, 'exclude_eids': ['NAD-P-OR-NOP', 'NADH-P-OR-NOP', 'Donor-H2', 'Acceptor', 'HYDROGEN-PEROXIDE', 'OXYGEN-MOLECULE', 'NAD', 'NADP', 'NADH', 'NADPH', 'WATER', 'CARBON-DIOXIDE', 'FAD', 'CO-A', 'UDP', 'AMMONIA', 'NA+', 'AMMONIUM', 'PROTON', 'CARBON-MONOXIDE', 'GTP', 'ADP', 'GDP', 'AMP', 'ATP', '3-5-ADP', 'PPI', 'Pi']}, relationships_query="\nUNWIND apoc.coll.combinations($term_match, 2) AS termPair\nUNWIND termPair[0]['matches'] as matchA\nUNWIND termPair[1]['matches'] as matchB\nWITH matchA, matchB, matchA['similarity'] * matchB['similarity'] AS similarity\nORDER BY similarity DESC\nWHERE similarity > 0.5\nMATCH (a), (b)\nWHERE id(a) = matchA['id'] AND id(b) = matchB['id']\nMATCH path=allShortestPaths((a)-[*1..]-(b))\nWHERE\n all(r in relationships(path) where type(r) in $include_rels)\n and all(n in nodes(path) where not n.eid in $exclude_eids)\nRETURN path LIMIT $top_k\n", relationships_query_params={'top_k': 5, 'include_rels': ['CONSUMED_BY', 'PRODUCES', 'CATALYZES', 'REGULATES', 'HAS_TXONOMY', 'IS', 'HAS_KO', 'ELEMENT_OF', 'ENCODES'], 'exclude_eids': ['NAD-P-OR-NOP', 'NADH-P-OR-NOP', 'Donor-H2', 'Acceptor', 'HYDROGEN-PEROXIDE', 'OXYGEN-MOLECULE', 'NAD', 'NADP', 'NADH', 'NADPH', 'WATER', 'CARBON-DIOXIDE', 'FAD', 'CO-A', 'UDP', 'AMMONIA', 'NA+', 'AMMONIUM', 'PROTON', 'CARBON-MONOXIDE', 'GTP', 'ADP', 'GDP', 'AMP', 'ATP', '3-5-ADP', 'PPI', 'Pi']}), verbose=True)

# %% [markdown]
# ### Define callback handler

# %%
from langchain.callbacks.stdout import StdOutCallbackHandler
handler = StdOutCallbackHandler()
handler

# %% [markdown]
# ### Init QA chain

# %%
from langchain.chains import RetrievalQA

# %%
qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    verbose=True,
    callbacks=[handler]
)
qa
# Out:
# RetrievalQA(memory=None, callbacks=[<langchain.callbacks.stdout.StdOutCallbackHandler object at 0x7f5937940810>], callback_manager=None, verbose=True, tags=None, metadata=None, combine_documents_chain=StuffDocumentsChain(memory=None, callbacks=None, callback_manager=None, verbose=False, tags=None, metadata=None, input_key='input_documents', output_key='output_text', llm_chain=LLMChain(memory=None, callbacks=None, callback_manager=None, verbose=False, tags=None, metadata=None, prompt=ChatPromptTemplate(input_variables=['context', 'question'], output_parser=None, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context'], output_parser=None, partial_variables={}, template="Use the following pieces of context to answer the users question. \nIf you don't know the answer, just say that you don't know, don't try to make up an answer.\n----------------\n{context}", template_format='f-string', validate_template=True), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['question'], output_parser=None, partial_variables={}, template='{question}', template_format='f-string', validate_template=True), additional_kwargs={})]), llm=ChatOpenAI(cache=None, verbose=True, callbacks=None, callback_manager=None, tags=None, metadata=None, client=<class 'openai.api_resources.chat_completion.ChatCompletion'>, model_name='gpt-3.5-turbo', temperature=0.0, model_kwargs={}, openai_api_key='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', openai_api_base='', openai_organization='', openai_proxy='', request_timeout=None, max_retries=6, streaming=False, n=1, max_tokens=None, tiktoken_model_name=None), output_key='text', output_parser=StrOutputParser(), return_final_only=True, llm_kwargs={}), document_prompt=PromptTemplate(input_variables=['page_content'], output_parser=None, partial_variables={}, template='{page_content}', template_format='f-string', validate_template=True), document_variable_name='context', document_separator='\n\n'), input_key='query', output_key='result', return_source_documents=False, retriever=GraphSearchRetriever(tags=None, metadata=None, vectorstore=<langchain.vectorstores.chroma.Chroma object at 0x7f593f7b7c50>, llm_chain=LLMChain(memory=None, callbacks=None, callback_manager=None, verbose=False, tags=None, metadata=None, prompt=ChatPromptTemplate(input_variables=['query'], output_parser=None, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], output_parser=None, partial_variables={}, template='Always response with comma separated list of chemical or biological terms identified in prompt.', template_format='f-string', validate_template=True), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['query'], output_parser=None, partial_variables={}, template='{query}', template_format='f-string', validate_template=True), additional_kwargs={})]), llm=ChatOpenAI(cache=None, verbose=True, callbacks=None, callback_manager=None, tags=None, metadata=None, client=<class 'openai.api_resources.chat_completion.ChatCompletion'>, model_name='gpt-3.5-turbo', temperature=0.0, model_kwargs={}, openai_api_key='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', openai_api_base='', openai_organization='', openai_proxy='', request_timeout=None, max_retries=6, streaming=False, n=1, max_tokens=None, tiktoken_model_name=None), output_key='text', output_parser=CommaSeparatedListOutputParser(), return_final_only=True, llm_kwargs={}), graph_search=CypherSearchAPIWrapper(graph=<llmlib.utils.lazy_neo4j_graph.LazyNeo4jGraph object at 0x7f593ddfabd0>, related_nodes_query='\nUNWIND $terms AS term\nMATCH (s:Synonym {lowercase_name: toLower(term)})<-[:HAS_SYNONYM]-(n)\nWHERE n.eid IS NOT NULL AND NOT n.eid IN $exclude_eids\nWITH apoc.text.levenshteinSimilarity(term, n.name) as similarity, s, n, term\nORDER BY similarity DESC\nWHERE similarity > 0.5\nWITH DISTINCT term, collect({node: n,  ...

# %% [markdown]
# # Test

# %% [markdown]
# ## Initial query

# %%
qa.run(query, callbacks=[handler])
# Out:
# > Entering new RetrievalQA chain...
#
# 	>> Generating list of revelant terms
# 	Identified Terms:
# 	['Zn2+', 'glycolate']
#
# 	>> Searching for related graph nodes
# 	Identified Nodes:
# 	[{'term': 'Zn2+', 'matches': [{'node': {'original_entity_types': ['Compound'], 'eid': 'ZN+2', 'inchi': 'InChI=1S/Zn/q+2', 'abbrev_name': '', 'smiles': '[Zn+2]', 'entityType': 'Chemical', 'displayName': 'Zn2+', 'inchi_key': 'PTFCDOFLOPIGGS-UHFFFAOYSA-N', 'name': 'Zn2+', 'biocyc_id': 'ZN+2', 'data_source': 'BioCyc'}, 'similarity': 1.0, 'node_id': 3703030}]}, {'term': 'glycolate', 'matches': [{'node': {'original_entity_types': ['Compound'], 'eid': 'GLYCOLLATE', 'inchi': 'InChI=1S/C2H4O3/c3-1-2(4)5/h3H,1H2,(H,4,5)/p-1', 'abbrev_name': '', 'smiles': 'C(C(=O)[O-])O', 'entityType': 'Chemical', 'displayName': 'glycolate', 'inchi_key': 'AEMRFAOFKBGASW-UHFFFAOYSA-M', 'name': 'glycolate', 'biocyc_id': 'GLYCOLLATE', 'data_source': 'BioCyc'}, 'similarity': 1.0, 'node_id': 3703369}, {'node': {'original_entity_types': ['Chemical'], 'eid': '29805', 'inchi_key': 'AEMRFAOFKBGASW-UHFFFAOYSA-M', 'name': 'glycolate', 'data_source': 'ChEBI', 'alt_id': 'CHEBI:14348|CHEBI:24388'}, 'similarity': 1.0, 'node_id': 11166676}, {'node': {'original_entity_types': ['Chemical'], 'eid': 'C031149', 'obsolete': 0, 'name': 'glycolic acid', 'mesh_id': 'C031149', 'data_source': 'MeSH'}, 'similarity': 0.5384615384615384, 'node_id': 9967120}]}]
#
# 	>> Searching for related graph relationships
#
# 	Identified Relationships:
# 	[{'path': [{'original_entity_types': ['Compound'], 'eid': 'ZN+2', 'inchi': 'InChI=1S/Zn/q+2', 'abbrev_name': '', 'smiles': '[Zn+2]', 'entityType': 'Chemical', 'displayName': 'Zn2+', 'inchi_key': 'PTFCDOFLOPIGGS-UHFFFAOYSA-N', 'name': 'Zn2+', 'biocyc_id': 'ZN+2', 'data_source': 'BioCyc'}, 'REGULATES', {'mode': '-', 'eid': 'REG0-12395', 'displayName': 'Regulation-of-Enzyme-Activity (-)', 'type': 'Regulation-of-Enzyme-Activity', 'biocyc_id': 'REG0-12395'}, 'REGULATES', {'eid': 'ENZRXN0-8126', 'genes': 'yajL', 'displayName': 'glyoxalase III', 'name': 'glyoxalase III', 'description': 'complex of protein/nucleic acid deglycase 3 YajL, catalyzes reaction: H2O + glyoxal --> H+ + glycolate', 'biocyc_id': 'ENZRXN0-8126'}, 'CATALYZES', {'eid': 'RXN0-7173', 'entityType': 'Reaction', 'displayName': 'EC-4.2.1', 'ec_number': 'EC-4.2.1', 'name': 'RXN0-7173', 'description': 'Hydro-lyases: H2O + glyoxal --> H+ + glycolate', 'detail': 'H2O + glyoxal => H+ + glycolate', 'biocyc_id': 'RXN0-7173'}, 'PRODUCES', {'original_entity_types': ['Compound'], 'eid': 'GLYCOLLATE', 'inchi': 'InChI=1S/C2H4O3/c3-1-2(4)5/h3H,1H2,(H,4,5)/p-1', 'abbrev_name': '', 'smiles': 'C(C(=O)[O-])O', 'entityType': 'Chemical', 'displayName': 'glycolate', 'inchi_key': 'AEMRFAOFKBGASW-UHFFFAOYSA-M', 'name': 'glycolate', 'biocyc_id': 'GLYCOLLATE', 'data_source': 'BioCyc'}]}, {'path': [{'original_entity_types': ['Compound'], 'eid': 'ZN+2', 'inchi': 'InChI=1S/Zn/q+2', 'abbrev_name': '', 'smiles': '[Zn+2]', 'entityType': 'Chemical', 'displayName': 'Zn2+', 'inchi_key': 'PTFCDOFLOPIGGS-UHFFFAOYSA-N', 'name': 'Zn2+', 'biocyc_id': 'ZN+2', 'data_source': 'BioCyc'}, 'REGULATES', {'mode': '-', 'eid': 'REG0-9208', 'displayName': 'Regulation-of-Enzyme-Activity (-)', 'type': 'Regulation-of-Enzyme-Activity', 'biocyc_id': 'REG0-9208'}, 'REGULATES', {'eid': 'GLYCOLALD-DEHYDROG-ENZRXN', 'genes': 'aldA', 'displayName': 'glycolaldehyde dehydrogenase', 'name': 'glycolaldehyde dehydrogenase', 'description': 'complex of aldehyde dehydrogenase A AldA, catalyzes reaction: glycolaldehyde + NAD+ + H2O --> glycolate + NADH + H+', 'biocyc_id': 'GLYCOLALD-DEHYDROG-ENZRXN'}, 'CATALYZES', {'eid': 'GLYCOLALD-DEHYDROG-RXN', 'entityType': 'Reaction', 'ec_number': 'EC-1.2.1.21', 'displayName': 'EC-1.2.1.21', 'name': '', 'description': 'Glycolaldehyde dehydrogenase: glycolaldehyde + NAD+ + H2O --> glycolate + NADH + H+', 'location': '', 'detail': 'glycolaldehyde + NAD+ + H2O => glycolate + NADH + H+', 'biocyc_id': 'GLYCOLALD-DEHYDROG-RXN', 'data_source': 'BioCyc', 'direction': ''}, 'PRODUCES', {'original_entity_types': ['Compound'], 'eid': 'GLYCOLLATE', 'inchi': 'InChI=1S/C2H4O3/c3-1-2(4)5/h3H,1H2,(H,4,5)/p-1', 'abbrev_name': '', 'smiles': 'C(C(=O)[O-])O', 'entityType': 'Chemical', 'displayName': 'glycolate', 'inchi_key': 'AEMRFAOFKBGASW-UHFFFAOYSA-M', 'name': 'glycolate', 'biocyc_id': 'GLYCOLLATE', 'data_source': 'BioCyc'}]}, {'path': [{'original_entity_types': ['Compound'], 'eid': 'ZN+2', 'inchi': 'InChI=1S/Zn/q+2', 'abbrev_name': '', 'smiles': '[Zn+2]', 'entityType': 'Chemical', 'displayName': 'Zn2+', 'inchi_key': 'PTFCDOFLOPIGGS-UHFFFAOYSA-N', 'name': 'Zn2+', 'biocyc_id': 'ZN+2', 'data_source': 'BioCyc'}, 'REGULATES', {'mode': '-', 'eid': 'REG0-10246', 'displayName': 'Regulation-of-Enzyme-Activity (-)', 'type': 'Regulation-of-Enzyme-Activity', 'biocyc_id': 'REG0-10246'}, 'REGULATES', {'eid': 'GLYCOLATEDEHYDRO-ENZRXN', 'genes': 'glcD, glcE, glcF', 'displayName': 'glycolate dehydrogenase', 'name': 'glycolate dehydrogenase', 'description': 'complex of glycolate dehydrogenase, putative FAD-binding subunit GlcE, glycolate dehydrogenase, putative FAD-linked subunit GlcD, glycolate dehydrogenase, putative iron-sulfur subunit GlcF, catalyzes reaction: glycolate + oxidized unknown electron carrier --> glyoxylate + reduced unknown two electron carrier', 'biocyc_id': 'GLYCOLATEDEHYDRO-ENZRXN'}, 'CATALYZES', {'eid': 'GLYCOLATEDEHYDRO-RXN', 'entityType': 'Reaction', 'ec_number': 'EC-1.1.99.14', 'displayName': 'EC-1.1.99.14 ...
#
#
#
# > Entering new StuffDocumentsChain chain...
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# System: Use the following pieces of context to answer the users question.
# If you don't know the answer, just say that you don't know, don't try to make up an answer.
# ----------------
# Zn2+:
# - matches:
#   - eid: ZN+2
#     name: Zn2+
#     similarity: 1.0
#
#
# glycolate:
# - matches:
#   - eid: GLYCOLLATE
#     name: glycolate
#     similarity: 1.0
#   - eid: '29805'
#     name: glycolate
#     similarity: 1.0
#   - eid: C031149
#     name: glycolic acid
#     similarity: 0.5384615384615384
#
#
# relationship:
#   nodes:
#     ENZRXN0-8126:
#       description: 'complex of protein/nucleic acid deglycase 3 YajL, catalyzes reaction:
#         H2O + glyoxal --> H+ + glycolate'
#       name: glyoxalase III
#       type: null
#     GLYCOLLATE:
#       description: null
#       name: glycolate
#       type: Chemical
#     REG0-12395:
#       description: null
#       name: Regulation-of-Enzyme-Activity (-)
#       type: Regulation-of-Enzyme-Activity
#     RXN0-7173:
#       description: 'Hydro-lyases: H2O + glyoxal --> H+ + glycolate'
#       name: EC-4.2.1
#       type: Reaction
#     ZN+2:
#       description: null
#       name: Zn2+
#       type: Chemical
#   path: ZN+2 - REGULATES - REG0-12395 - REGULATES - ENZRXN0-8126 - CATALYZES - RXN0-7173
#     - PRODUCES - GLYCOLLATE
#
#
# relationship:
#   nodes:
#     GLYCOLALD-DEHYDROG-ENZRXN:
#       description: 'complex of aldehyde dehydrogenase A AldA, catalyzes reaction:
#         glycolaldehyde + NAD+ + H2O --> glycolate + NADH + H+'
#       name: glycolaldehyde dehydrogenase
#       type: null
#     GLYCOLALD-DEHYDROG-RXN:
#       description: 'Glycolaldehyde dehydrogenase: glycolaldehyde + NAD+ + H2O -->
#         glycolate + NADH + H+'
#       name: EC-1.2.1.21
#       type: Reaction
#     GLYCOLLATE:
#       description: null
#       name: glycolate
#       type: Chemical
#     REG0-9208:
#       description: null
#       name: Regulation-of-Enzyme-Activity (-)
#       type: Regulation-of-Enzyme-Activity
#     ZN+2:
#       description: null
#       name: Zn2+
#       type: Chemical
#   path: ZN+2 - REGULATES - REG0-9208 - REGULATES - GLYCOLALD-DEHYDROG-ENZRXN - CATALYZES
#     - GLYCOLALD-DEHYDROG-RXN - PRODUCES - GLYCOLLATE
#
#
# relationship:
#   nodes:
#     GLYCOLATEDEHYDRO-ENZRXN:
#       description: 'complex of glycolate dehydrogenase, putative FAD-binding subunit
#         GlcE, glycolate dehydrogenase, putative FAD-linked subunit GlcD, glycolate
#         dehydrogenase, putative iron-sulfur subunit GlcF, catalyzes reaction: glycolate
#         + oxidized unknown electron carrier --> glyoxylate + reduced unknown two electron
#         carrier'
#       name: glycolate dehydrogenase
#       type: null
#     GLYCOLATEDEHYDRO-RXN:
#       description: 'Glycolate dehydrogenase: glycolate + oxidized unknown electron
#         carrier --> glyoxylate + reduced unknown two electron carrier'
#       name: EC-1.1.99.14
#       type: Reaction
#     GLYCOLLATE:
#       description: null
#       name: glycolate
#       type: Chemical
#     REG0-10246:
#       description: null
#       name: Regulation-of-Enzyme-Activity (-)
#       type: Regulation-of-Enzyme-Activity
#     ZN+2:
#       description: null
#       name: Zn2+
#       type: Chemical
#   path: ZN+2 - REGULATES - REG0-10246 - REGULATES - GLYCOLATEDEHYDRO-ENZRXN - CATALYZES
#     - GLYCOLATEDEHYDRO-RXN - CONSUMED_BY - GLYCOLLATE
#
# Human: What is the relationship between Zn2+ and glycolate?
#
# > Finished chain.
#
# > Finished chain.
#
# > Finished chain.
# 'The relationship between Zn2+ and glycolate is that Zn2+ regulates the production of glycolate.'

# %%
from langchain.prompts.chat import (
    ChatPromptTemplate,
    HumanMessagePromptTemplate,
    SystemMessagePromptTemplate,
)
system_template = """Use the following pieces of context to answer the users question. 
If you don't know the answer, just say that you don't know, don't try to make up an answer.
Work on the answear in two steps:
1. Rephase pieces of context ussing natural language
2. Based on repharsed text respond to the question
----------------
{context}
----------------"""
RetrievalQA.from_chain_type(
    llm=llm,
    prompt=ChatPromptTemplate.from_messages([
        SystemMessagePromptTemplate.from_template(system_template),
        HumanMessagePromptTemplate.from_template("{question}"),
    ]),
    chain_type="stuff",
    retriever=retriever,
    verbose=True,
    callbacks=[handler]
).run(query, callbacks=[handler])

# %%
chatGPTQA(query)
# Out:
# <OpenAIObject chat.completion id=chatcmpl-8Da255JNLFgBALNhBWDaudgJT9pCL at 0x7f593f677fb0> JSON: {
#   "id": "chatcmpl-8Da255JNLFgBALNhBWDaudgJT9pCL",
#   "object": "chat.completion",
#   "created": 1698247465,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "The relationship between Zn2+ and glycolate is that Zn2+ can form a complex with glycolate. In this complex, the Zn2+ ion binds to the oxygen atoms in the glycolate molecule, forming coordination bonds. This interaction between Zn2+ and glycolate allows for the stabilization and transport of glycolate in biological systems."
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 21,
#     "completion_tokens": 77,
#     "total_tokens": 98
#   }
# }

# %% [markdown]
# ## Other checks

# %%
query1 = "What is the association between putrescine and zinT?"
qa.run(query1, callbacks=[handler])
# Out:
# > Entering new RetrievalQA chain...
#
# 	>> Generating list of revelant terms
# 	Identified Terms:
# 	['putrescine', 'zinT']
#
# 	>> Searching for related graph nodes
# 	Identified Nodes:
# 	[{'term': 'putrescine', 'matches': [{'node': {'original_entity_types': ['Chemical'], 'eid': '17148', 'inchi_key': 'KIDHWZJUCRJVML-UHFFFAOYSA-N', 'name': 'putrescine', 'data_source': 'ChEBI', 'alt_id': 'CHEBI:26405|CHEBI:14972|CHEBI:8650|CHEBI:45092'}, 'similarity': 1.0, 'node_id': 11208475}, {'node': {'original_entity_types': ['Compound'], 'eid': 'PUTRESCINE', 'inchi': 'InChI=1S/C4H12N2/c5-3-1-2-4-6/h1-6H2/p+2', 'abbrev_name': '', 'smiles': 'C([NH3+])CCC[NH3+]', 'entityType': 'Chemical', 'displayName': 'putrescine', 'inchi_key': 'KIDHWZJUCRJVML-UHFFFAOYSA-P', 'name': 'putrescine', 'biocyc_id': 'PUTRESCINE', 'data_source': 'BioCyc'}, 'similarity': 1.0, 'node_id': 3743644}, {'node': {'original_entity_types': ['Chemical'], 'eid': '17148', 'inchi_key': 'KIDHWZJUCRJVML-UHFFFAOYSA-N', 'name': 'putrescine', 'data_source': 'ChEBI', 'alt_id': 'CHEBI:26405|CHEBI:14972|CHEBI:8650|CHEBI:45092'}, 'similarity': 1.0, 'node_id': 11208475}, {'node': {'original_entity_types': ['Chemical'], 'eid': 'D011700', 'obsolete': 0, 'name': 'Putrescine', 'mesh_id': 'D011700', 'data_source': 'MeSH'}, 'similarity': 0.9, 'node_id': 83309831}]}, {'term': 'zinT', 'matches': [{'node': {'original_entity_types': ['Gene'], 'eid': '63142423', 'full_name': 'metal-binding protein ZinT', 'name': 'zinT', 'locus_tag': 'FY206_RS12300', 'data_source': 'NCBI Gene', 'tax_id': '2494701'}, 'similarity': 1.0, 'node_id': 98152555}, {'node': {'left_end_position': '2741357', 'eid': 'BSU26830', 'strand': '-', 'entityType': 'Gene', 'displayName': 'zinT', 'right_end_position': '2742112', 'name': 'zinT', 'description': 'lipoprotein buffering protein for Zn2+ transport', 'accession': 'BSU26830', 'biocyc_id': 'BSU26830', 'data_source': 'BioCyc'}, 'similarity': 1.0, 'node_id': 21732636}, {'node': {'original_entity_types': ['Gene'], 'eid': '61284013', 'full_name': 'metal-binding protein ZinT', 'name': 'zinT', 'locus_tag': 'FN077_RS06470', 'data_source': 'NCBI Gene', 'tax_id': '2587529'}, 'similarity': 1.0, 'node_id': 98115080}, {'node': {'original_entity_types': ['Gene'], 'eid': '64339080', 'full_name': 'metal-binding protein ZinT', 'name': 'zinT', 'locus_tag': 'FN634_RS21865', 'data_source': 'NCBI Gene', 'tax_id': '2058152'}, 'similarity': 1.0, 'node_id': 97984289}, {'node': {'original_entity_types': ['Gene'], 'eid': '61330466', 'full_name': 'metal-binding protein ZinT', 'name': 'zinT', 'locus_tag': 'E9626_RS04485', 'data_source': 'NCBI Gene', 'tax_id': '2026240'}, 'similarity': 1.0, 'node_id': 98063070}, {'node': {'original_entity_types': ['Gene'], 'eid': '63938107', 'full_name': 'metal-binding protein ZinT', 'name': 'zinT', 'locus_tag': 'I6M86_RS06355', 'data_source': 'NCBI Gene', 'tax_id': '1748967'}, 'similarity': 1.0, 'node_id': 97807889}, {'node': {'original_entity_types': ['Gene'], 'eid': '61124212', 'full_name': 'metal-binding protein ZinT', 'name': 'zinT', 'locus_tag': 'FOB25_RS01705', 'data_source': 'NCBI Gene', 'tax_id': '1639133'}, 'similarity': 1.0, 'node_id': 97810078}, {'node': {'original_entity_types': ['Gene'], 'eid': '60668850', 'full_name': 'metal-binding protein ZinT', 'name': 'zinT', 'locus_tag': 'EL192_RS12435', 'data_source': 'NCBI Gene', 'tax_id': '1499973'}, 'similarity': 1.0, 'node_id': 97624644}, {'node': {'original_entity_types': ['Gene'], 'eid': '45571988', 'full_name': 'metal-binding protein ZinT', 'name': 'zinT', 'locus_tag': 'AT01_RS14080', 'data_source': 'NCBI Gene', 'tax_id': '1453495'}, 'similarity': 1.0, 'node_id': 97640911}, {'node': {'original_entity_types': ['Gene'], 'eid': '64297769', 'full_name': 'metal-binding protein ZinT', 'name': 'zinT', 'locus_tag': 'I8N75_RS24655', 'data_source': 'NCBI Gene', 'tax_id': '1463165'}, 'similarity': 1.0, 'node_id': 97632276}]}]
#
# 	>> Searching for related graph relationships
#
# 	Identified Relationships:
# 	[{'path': [{'original_entity_types': ['Compound'], 'eid': 'PUTRESCINE', 'inchi': 'InChI=1S/C4H12N2/c5-3-1-2-4-6/h1-6H2/p+2', 'abbrev_name': '', 'smiles': 'C([NH3+])CCC[NH3+]', 'entityType': 'Chemical', 'displayName': 'putrescine', 'inchi_key': 'KIDHWZJUCRJVML-UHFFFAOYSA-P', 'name': 'putrescine', 'biocyc_id': 'PUTRESCINE', 'data_source': 'BioCyc'}, 'CONSUMED_BY', {'eid': 'PUTTRANSAM-RXN', 'entityType': 'Reaction', 'displayName': 'PUTTRANSAM-RXN', 'name': 'PUTTRANSAM-RXN', 'description': '2-oxoglutarate + putrescine --> L-glutamate + 4-aminobutanal', 'detail': '2-oxoglutarate + putrescine => L-glutamate + 4-aminobutanal', 'biocyc_id': 'PUTTRANSAM-RXN'}, 'PRODUCES', {'original_entity_types': ['Compound'], 'eid': 'GLT', 'inchi': 'InChI=1S/C5H9NO4/c6-3(5(9)10)1-2-4(7)8/h3H,1-2,6H2,(H,7,8)(H,9,10)/p-1/t3-/m0/s1', 'abbrev_name': 'glu', 'smiles': 'C(CC[C@@H](C(=O)[O-])[NH3+])([O-])=O', 'entityType': 'Chemical', 'displayName': 'L-glutamate', 'inchi_key': 'WHUUTDBJXJRKMK-VKHMYHEASA-M', 'name': 'L-glutamate', 'biocyc_id': 'GLT', 'data_source': 'BioCyc'}, 'REGULATES', {'mode': '+', 'eid': 'REG0-11302', 'displayName': 'Regulation-of-Enzyme-Activity (+)', 'type': 'Regulation-of-Enzyme-Activity', 'biocyc_id': 'REG0-11302'}, 'REGULATES', {'eid': 'MALIC-NADP-ENZRXN', 'genes': 'maeB', 'displayName': 'malate dehydrogenase', 'name': 'malate dehydrogenase', 'description': 'complex of malate dehydrogenase MaeB, catalyzes reaction: (S)-malate + NADP+ --> pyruvate + CO2 + NADPH', 'biocyc_id': 'MALIC-NADP-ENZRXN'}, 'REGULATES', {'mode': '-', 'eid': 'REG0-11311', 'displayName': 'Regulation-of-Enzyme-Activity (-)', 'type': 'Regulation-of-Enzyme-Activity', 'biocyc_id': 'REG0-11311'}, 'REGULATES', {'original_entity_types': ['Compound'], 'eid': 'ZN+2', 'inchi': 'InChI=1S/Zn/q+2', 'abbrev_name': '', 'smiles': '[Zn+2]', 'entityType': 'Chemical', 'displayName': 'Zn2+', 'inchi_key': 'PTFCDOFLOPIGGS-UHFFFAOYSA-N', 'name': 'Zn2+', 'biocyc_id': 'ZN+2', 'data_source': 'BioCyc'}, 'CONSUMED_BY', {'eid': 'RXN8J2-91', 'entityType': 'Reaction', 'displayName': '', 'ec_number': '', 'name': '', 'location': '', 'detail': 'Zn2+ + transcriptional regulator Zur => Zur-Zinc', 'biocyc_id': 'RXN8J2-91', 'data_source': 'BioCyc', 'direction': ''}, 'PRODUCES', {'eid': 'CPLX8J2-114', 'molecular_weight_kd': '', 'abbrev_name': '', 'displayName': 'Zur-Zinc', 'entityType': 'Protein', 'name': 'Zur-Zinc', 'description': 'complex of Zn2+ and transcriptional regulator (Zn[2+]-binding Fur family)', 'pi': '', 'biocyc_id': 'CPLX8J2-114', 'data_source': 'BioCyc'}, 'REGULATES', {'mode': '-', 'eid': 'REG8J2-17923', 'displayName': 'Transcription-Factor-Binding (-)', 'mechanism': '', 'biocyc_id': 'REG8J2-17923', 'data_source': 'BioCyc'}, 'REGULATES', {'eid': 'PM8J2-1222', 'strand': '-', 'entityType': 'Promoter', 'displayName': 'zinTp', 'pos_1': '', 'name': 'zinTp', 'description': 'Promoter for lipoprotein buffering protein for Zn2+ transport', 'biocyc_id': 'PM8J2-1222', 'data_source': 'BioCyc'}, 'ELEMENT_OF', {'eid': 'TU8J2-2980', 'entityType': 'TranscriptionUnit', 'displayName': 'zinT (tu)', 'name': 'zinT', 'description': 'TranscriptionUnit for lipoprotein buffering protein for Zn2+ transport', 'biocyc_id': 'TU8J2-2980', 'data_source': 'BioCyc'}, 'ELEMENT_OF', {'left_end_position': '2741357', 'eid': 'BSU26830', 'strand': '-', 'entityType': 'Gene', 'displayName': 'zinT', 'right_end_position': '2742112', 'name': 'zinT', 'description': 'lipoprotein buffering protein for Zn2+ transport', 'accession': 'BSU26830', 'biocyc_id': 'BSU26830', 'data_source': 'BioCyc'}]}, {'path': [{'original_entity_types': ['Compound'], 'eid': 'PUTRESCINE', 'inchi': 'InChI=1S/C4H12N2/c5-3-1-2-4-6/h1-6H2/p+2', 'abbrev_name': '', 'smiles': 'C([NH3+])CCC[NH3+]', 'entityType': 'Chemical', 'displayName': 'putrescine', 'inchi_key': 'KIDHWZJUCRJVML-UHFFFAOYSA-P', 'name': 'putrescine', 'biocyc_id': 'PUTRESCINE', 'data_source': 'BioCyc'}, 'PRODUCES', {'eid': 'TRANS-RXN0-211', 'entityType': 'Reaction', 'displayName': 'TRANS-RXN0-211' ...
#
#
#
# > Entering new StuffDocumentsChain chain...
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# System: Use the following pieces of context to answer the users question.
# If you don't know the answer, just say that you don't know, don't try to make up an answer.
# ----------------
# putrescine:
# - matches:
#   - eid: '17148'
#     name: putrescine
#     similarity: 1.0
#   - eid: PUTRESCINE
#     name: putrescine
#     similarity: 1.0
#   - eid: '17148'
#     name: putrescine
#     similarity: 1.0
#   - eid: D011700
#     name: Putrescine
#     similarity: 0.9
#
#
# zinT:
# - matches:
#   - eid: '63142423'
#     name: zinT
#     similarity: 1.0
#   - eid: BSU26830
#     name: zinT
#     similarity: 1.0
#   - eid: '61284013'
#     name: zinT
#     similarity: 1.0
#   - eid: '64339080'
#     name: zinT
#     similarity: 1.0
#   - eid: '61330466'
#     name: zinT
#     similarity: 1.0
#   - eid: '63938107'
#     name: zinT
#     similarity: 1.0
#   - eid: '61124212'
#     name: zinT
#     similarity: 1.0
#   - eid: '60668850'
#     name: zinT
#     similarity: 1.0
#   - eid: '45571988'
#     name: zinT
#     similarity: 1.0
#   - eid: '64297769'
#     name: zinT
#     similarity: 1.0
#
#
# relationship:
#   nodes:
#     BSU26830:
#       description: lipoprotein buffering protein for Zn2+ transport
#       name: zinT
#       type: Gene
#     CPLX8J2-114:
#       description: complex of Zn2+ and transcriptional regulator (Zn[2+]-binding Fur
#         family)
#       name: Zur-Zinc
#       type: Protein
#     GLT:
#       description: null
#       name: L-glutamate
#       type: Chemical
#     MALIC-NADP-ENZRXN:
#       description: 'complex of malate dehydrogenase MaeB, catalyzes reaction: (S)-malate
#         + NADP+ --> pyruvate + CO2 + NADPH'
#       name: malate dehydrogenase
#       type: null
#     PM8J2-1222:
#       description: Promoter for lipoprotein buffering protein for Zn2+ transport
#       name: zinTp
#       type: Promoter
#     PUTRESCINE:
#       description: null
#       name: putrescine
#       type: Chemical
#     PUTTRANSAM-RXN:
#       description: 2-oxoglutarate + putrescine --> L-glutamate + 4-aminobutanal
#       name: PUTTRANSAM-RXN
#       type: Reaction
#     REG0-11302:
#       description: null
#       name: Regulation-of-Enzyme-Activity (+)
#       type: Regulation-of-Enzyme-Activity
#     REG0-11311:
#       description: null
#       name: Regulation-of-Enzyme-Activity (-)
#       type: Regulation-of-Enzyme-Activity
#     REG8J2-17923:
#       description: null
#       name: Transcription-Factor-Binding (-)
#       type: null
#     RXN8J2-91:
#       description: null
#       name: ''
#       type: Reaction
#     TU8J2-2980:
#       description: TranscriptionUnit for lipoprotein buffering protein for Zn2+ transport
#       name: zinT (tu)
#       type: TranscriptionUnit
#     ZN+2:
#       description: null
#       name: Zn2+
#       type: Chemical
#   path: PUTRESCINE - CONSUMED_BY - PUTTRANSAM-RXN - PRODUCES - GLT - REGULATES - REG0-11302
#     - REGULATES - MALIC-NADP-ENZRXN - REGULATES - REG0-11311 - REGULATES - ZN+2 -
#     CONSUMED_BY - RXN8J2-91 - PRODUCES - CPLX8J2-114 - REGULATES - REG8J2-17923 -
#     REGULATES - PM8J2-1222 - ELEMENT_OF - TU8J2-2980 - ELEMENT_OF - BSU26830
#
#
# relationship:
#   nodes:
#     BSU26830:
#       description: lipoprotein buffering protein for Zn2+ transport
#       name: zinT
#       type: Gene
#     CPLX8J2-114:
#       description: complex of Zn2+ and transcriptional regulator (Zn[2+]-binding Fur
#         family)
#       name: Zur-Zinc
#       type: Protein
#     ENZRXN-11647:
#       description: 'complex of ornithine carbamoyltransferase OTC, catalyzes reaction:
#         carbamoyl phosphate + L-ornithine --> phosphate + L-citrulline + H+'
#       name: ornithine carbamoyltransferase
#       type: null
#     L-ORNITHINE:
#       description: null
#       name: L-ornithine
#       type: Chemical
#     ORNCARBAMTRANSFER-RXN:
#       description: 'Ornithine carbamoyltransferase: carbamoyl phosphate + L-ornithine
#         --> phosphate + L-citrulline + H+'
#       name: EC-2.1.3.3
#       type: Reaction
#     PM8J2-1222:
#       description: Promoter for lipoprotein buffering protein for Zn2+ transport
#       name: zinTp
#       type: Promoter
#     PUTRESCINE:
#       description: null
#       name: putrescine
#       type: Chemical
#     REG-10787:
#       description: null
#       name: Regulation-of-Enzyme-Activity (-)
#       type: null
#     REG8J2-17923:
#       description: null
#       name: Transcription-Factor-Binding (-)
#       type: null
#     RXN8J2-91:
#       description: null
#       name: ''
#       type: Reaction
#     TRANS-RXN0-211:
#       description: L-ornithine + putrescine --> L-ornithine + putrescine
#       name: TRANS-RXN0-211
#       type: Reaction
#     TU8J2-2980:
#       description: TranscriptionUnit for lipoprotein buffering protein for Zn2+ transport
#       name: zinT (tu)
#       type: TranscriptionUnit
#     ZN+2:
#       description: null
#       name: Zn2+
#       type: Chemical
#   path: PUTRESCINE - PRODUCES - TRANS-RXN0-211 - PRODUCES - L-ORNITHINE - CONSUMED_BY
#     - ORNCARBAMTRANSFER-RXN - CATALYZES - ENZRXN-11647 - REGULATES - REG-10787 - REGULATES
#     - ZN+2 - CONSUMED_BY - RXN8J2-91 - PRODUCES - CPLX8J2-114 - REGULATES - REG8J2-17923
#     - REGULATES - PM8J2-1222 - ELEMENT_OF - TU8J2-2980 - ELEMENT_OF - BSU26830
#
#
# relationship:
#   nodes:
#     2.6.1.82-RXN:
#       description: 'Putrescine--2-oxoglutarate transaminase: 2-oxoglutarate + putrescine
#         --> H2O + 1-pyrroline + L-glutamate'
#       name: EC-2.6.1.82
#       type: Reaction
#     BSU26830:
#       description: lipoprotein buffering protein for Zn2+ transport
#       name: zinT
#       type: Gene
#     CPLX8J2-114:
#       description: complex of Zn2+ and transcriptional regulator (Zn[2+]-binding Fur
#         family)
#       name: Zur-Zinc
#       type: Protein
#     GLT:
#       description: null
#       name: L-glutamate
#       type: Chemical
#     GLUTDECARBOX-RXN:
#       description: 'Glutamate decarboxylase: L-glutamate + H+ --> 4-aminobutanoate
#         + CO2'
#       name: EC-4.1.1.15
#       type: Reaction
#     GLUTDECARBOXA-ENZRXN:
#       description: 'complex of glutamate decarboxylase A GadA, catalyzes reaction:
#         L-glutamate + H+ --> 4-aminobutanoate + CO2'
#       name: glutamate decarboxylase A
#       type: null
#     PM8J2-1222:
#       description: Promoter for lipoprotein buffering protein for Zn2+ transport
#       name: zinTp
#       type: Promoter
#     PUTRESCINE:
#       description: null
#       name: putrescine
#       type: Chemical
#     REG0-7166:
#       description: null
#       name: Regulation-of-Enzyme-Activity (-)
#       type: Regulation-of-Enzyme-Activity
#     REG8J2-17923:
#       description: null
#       name: Transcription-Factor-Binding (-)
#       type: null
#     RXN8J2-91:
#       description: null
#       name: ''
#       type: Reaction
#     TU8J2-2980:
#       description: TranscriptionUnit for lipoprotein buffering protein for Zn2+ transport
#       name: zinT (tu)
#       type: TranscriptionUnit
#     ZN+2:
#       description: null
#       name: Zn2+
#       type: Chemical
#   path: PUTRESCINE - CONSUMED_BY - 2.6.1.82-RXN - PRODUCES - GLT - CONSUMED_BY - GLUTDECARBOX-RXN
#     - CATALYZES - GLUTDECARBOXA-ENZRXN - REGULATES - REG0-7166 - REGULATES - ZN+2
#     - CONSUMED_BY - RXN8J2-91 - PRODUCES - CPLX8J2-114 - REGULATES - REG8J2-17923
#     - REGULATES - PM8J2-1222 - ELEMENT_OF - TU8J2-2980 - ELEMENT_OF - BSU26830
#
#
# relationship:
#   nodes:
#     BSU26830:
#       description: lipoprotein buffering protein for Zn2+ transport
#       name: zinT
#       type: Gene
#     CPLX8J2-114:
#       description: complex of Zn2+ and transcriptional regulator (Zn[2+]-binding Fur
#         family)
#       name: Zur-Zinc
#       type: Protein
#     ENZRXN-11647:
#       description: 'complex of ornithine carbamoyltransferase OTC, catalyzes reaction:
#         carbamoyl phosphate + L-ornithine --> phosphate + L-citrulline + H+'
#       name: ornithine carbamoyltransferase
#       type: null
#     L-ORNITHINE:
#       description: null
#       name: L-ornithine
#       type: Chemical
#     ORNCARBAMTRANSFER-RXN:
#       description: 'Ornithine carbamoyltransferase: carbamoyl phosphate + L-ornithine
#         --> phosphate + L-citrulline + H+'
#       name: EC-2.1.3.3
#       type: Reaction
#     ORNDECARBOX-RXN:
#       description: 'Ornithine decarboxylase: L-ornithine + H+ --> putrescine + CO2'
#       name: EC-4.1.1.17
#       type: Reaction
#     PM8J2-1222:
#       description: Promoter for lipoprotein buffering protein for Zn2+ transport
#       name: zinTp
#       type: Promoter
#     PUTRESCINE:
#       description: null
#       name: putrescine
#       type: Chemical
#     REG-10787:
#       description: null
#       name: Regulation-of-Enzyme-Activity (-)
#       type: null
#     REG8J2-17923:
#       description: null
#       name: Transcription-Factor-Binding (-)
#       type: null
#     RXN8J2-91:
#       description: null
#       name: ''
#       type: Reaction
#     TU8J2-2980:
#       description: TranscriptionUnit for lipoprotein buffering protein for Zn2+ transport
#       name: zinT (tu)
#       type: TranscriptionUnit
#     ZN+2:
#       description: null
#       name: Zn2+
#       type: Chemical
#   path: PUTRESCINE - PRODUCES - ORNDECARBOX-RXN - CONSUMED_BY - L-ORNITHINE - CONSUMED_BY
#     - ORNCARBAMTRANSFER-RXN - CATALYZES - ENZRXN-11647 - REGULATES - REG-10787 - REGULATES
#     - ZN+2 - CONSUMED_BY - RXN8J2-91 - PRODUCES - CPLX8J2-114 - REGULATES - REG8J2-17923
#     - REGULATES - PM8J2-1222 - ELEMENT_OF - TU8J2-2980 - ELEMENT_OF - BSU26830
#
#
# relationship:
#   nodes:
#     ACETYLORNDEACET-ENZRXN:
#       description: 'complex of acetylornithine deacetylase ArgE, catalyzes reaction:
#         H2O + N-acetyl-L-ornithine --> acetate + L-ornithine'
#       name: acetylornithine deacetylase
#       type: null
#     BSU26830:
#       description: lipoprotein buffering protein for Zn2+ transport
#       name: zinT
#       type: Gene
#     CPLX8J2-114:
#       description: complex of Zn2+ and transcriptional regulator (Zn[2+]-binding Fur
#         family)
#       name: Zur-Zinc
#       type: Protein
#     L-ORNITHINE:
#       description: null
#       name: L-ornithine
#       type: Chemical
#     ORNDECARBOX-RXN:
#       description: 'Ornithine decarboxylase: L-ornithine + H+ --> putrescine + CO2'
#       name: EC-4.1.1.17
#       type: Reaction
#     PM8J2-1222:
#       description: Promoter for lipoprotein buffering protein for Zn2+ transport
#       name: zinTp
#       type: Promoter
#     PUTRESCINE:
#       description: null
#       name: putrescine
#       type: Chemical
#     REG0-8082:
#       description: null
#       name: Regulation-of-Enzyme-Activity (-)
#       type: Regulation-of-Enzyme-Activity
#     REG0-8087:
#       description: null
#       name: Regulation-of-Enzyme-Activity (-)
#       type: Regulation-of-Enzyme-Activity
#     REG8J2-17923:
#       description: null
#       name: Transcription-Factor-Binding (-)
#       type: null
#     RXN8J2-91:
#       description: null
#       name: ''
#       type: Reaction
#     TU8J2-2980:
#       description: TranscriptionUnit for lipoprotein buffering protein for Zn2+ transport
#       name: zinT (tu)
#       type: TranscriptionUnit
#     ZN+2:
#       description: null
#       name: Zn2+
#       type: Chemical
#   path: PUTRESCINE - PRODUCES - ORNDECARBOX-RXN - CONSUMED_BY - L-ORNITHINE - REGULATES
#     - REG0-8082 - REGULATES - ACETYLORNDEACET-ENZRXN - REGULATES - REG0-8087 - REGULATES
#     - ZN+2 - CONSUMED_BY - RXN8J2-91 - PRODUCES - CPLX8J2-114 - REGULATES - REG8J2-17923
#     - REGULATES - PM8J2-1222 - ELEMENT_OF - TU8J2-2980 - ELEMENT_OF - BSU26830
#
# Human: What is the association between putrescine and zinT?
#
# > Finished chain.
#
# > Finished chain.
#
# > Finished chain.
# 'The association between putrescine and zinT is that putrescine is consumed by the reaction PUTRESCINE - CONSUMED_BY - PUTTRANSAM-RXN - PRODUCES - GLT, and zinT is a gene that is associated with the transport of Zn2+.'

# %%
chatGPTQA(query1)
# Out:
# <OpenAIObject chat.completion id=chatcmpl-8Da2CfuzwdusvvDDcBUgfZhq4Z4wS at 0x7f593790b710> JSON: {
#   "id": "chatcmpl-8Da2CfuzwdusvvDDcBUgfZhq4Z4wS",
#   "object": "chat.completion",
#   "created": 1698247472,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "Putrescine and zinT are both associated with zinc homeostasis in bacteria.\n\nPutrescine is a polyamine compound that is involved in various cellular processes, including cell growth, differentiation, and stress response. It is synthesized from the amino acid ornithine and plays a crucial role in maintaining cellular homeostasis.\n\nZinT, on the other hand, is a zinc transporter protein found in bacteria. It is responsible for the uptake of zinc ions into the cell, which is essential for many cellular processes, including DNA replication, transcription, and enzyme activity.\n\nThe association between putrescine and zinT lies in their involvement in zinc homeostasis. Studies have shown that putrescine can bind to zinc ions and form complexes, which can then be transported into the cell by zinc transporters like ZinT. This suggests that putrescine may play a role in zinc uptake and distribution within the cell.\n\nFurthermore, the expression of zinT has been found to be regulated by putrescine levels in some bacteria. For example, in Escherichia coli, putrescine has been shown to upregulate the expression of zinT, leading to increased zinc uptake. This suggests that putrescine may act as a signaling molecule to regulate zinc homeostasis through the modulation of zinT expression.\n\nOverall, the association between putrescine and zinT lies in their involvement in zinc homeostasis, with putrescine potentially playing a role in zinc uptake and distribution, and zinT being regulated by putrescine levels."
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 21,
#     "completion_tokens": 329,
#     "total_tokens": 350
#   }
# }

# %%
query2 = "What is the association between putrescine and zinc?"
qa.run(query2, callbacks=[handler])
# Out:
# > Entering new RetrievalQA chain...
#
# 	>> Generating list of revelant terms
# 	Identified Terms:
# 	['putrescine', 'zinc']
#
# 	>> Searching for related graph nodes
# 	Identified Nodes:
# 	[{'term': 'putrescine', 'matches': [{'node': {'original_entity_types': ['Chemical'], 'eid': '17148', 'inchi_key': 'KIDHWZJUCRJVML-UHFFFAOYSA-N', 'name': 'putrescine', 'data_source': 'ChEBI', 'alt_id': 'CHEBI:26405|CHEBI:14972|CHEBI:8650|CHEBI:45092'}, 'similarity': 1.0, 'node_id': 11208475}, {'node': {'original_entity_types': ['Compound'], 'eid': 'PUTRESCINE', 'inchi': 'InChI=1S/C4H12N2/c5-3-1-2-4-6/h1-6H2/p+2', 'abbrev_name': '', 'smiles': 'C([NH3+])CCC[NH3+]', 'entityType': 'Chemical', 'displayName': 'putrescine', 'inchi_key': 'KIDHWZJUCRJVML-UHFFFAOYSA-P', 'name': 'putrescine', 'biocyc_id': 'PUTRESCINE', 'data_source': 'BioCyc'}, 'similarity': 1.0, 'node_id': 3743644}, {'node': {'original_entity_types': ['Chemical'], 'eid': '17148', 'inchi_key': 'KIDHWZJUCRJVML-UHFFFAOYSA-N', 'name': 'putrescine', 'data_source': 'ChEBI', 'alt_id': 'CHEBI:26405|CHEBI:14972|CHEBI:8650|CHEBI:45092'}, 'similarity': 1.0, 'node_id': 11208475}, {'node': {'original_entity_types': ['Chemical'], 'eid': 'D011700', 'obsolete': 0, 'name': 'Putrescine', 'mesh_id': 'D011700', 'data_source': 'MeSH'}, 'similarity': 0.9, 'node_id': 83309831}]}, {'term': 'zinc', 'matches': [{'node': {'original_entity_types': ['Chemical'], 'eid': 'D015032', 'mesh_id': 'D015032', 'obsolete': 0, 'name': 'Zinc', 'data_source': 'MeSH'}, 'similarity': 0.75, 'node_id': 83286921}, {'node': {'original_entity_types': ['Chemical'], 'eid': '30185', 'inchi_key': 'HCHKCACWOHOZIP-UHFFFAOYSA-N', 'name': 'zinc(0)', 'data_source': 'ChEBI'}, 'similarity': 0.5714285714285714, 'node_id': 11397922}]}]
#
# 	>> Searching for related graph relationships
#
# 	Identified Relationships:
# 	[]
#
#
#
# > Entering new StuffDocumentsChain chain...
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# System: Use the following pieces of context to answer the users question.
# If you don't know the answer, just say that you don't know, don't try to make up an answer.
# ----------------
# putrescine:
# - matches:
#   - eid: '17148'
#     name: putrescine
#     similarity: 1.0
#   - eid: PUTRESCINE
#     name: putrescine
#     similarity: 1.0
#   - eid: '17148'
#     name: putrescine
#     similarity: 1.0
#   - eid: D011700
#     name: Putrescine
#     similarity: 0.9
#
#
# zinc:
# - matches:
#   - eid: D015032
#     name: Zinc
#     similarity: 0.75
#   - eid: '30185'
#     name: zinc(0)
#     similarity: 0.5714285714285714
#
# Human: What is the association between putrescine and zinc?
#
# > Finished chain.
#
# > Finished chain.
#
# > Finished chain.
# 'There is no specific association mentioned between putrescine and zinc in the provided context.'

# %%
chatGPTQA(query2)
# Out:
# <OpenAIObject chat.completion id=chatcmpl-8Da2OrDsn5wlK3tt85Lw0qmx9Z1wR at 0x7f593f6764b0> JSON: {
#   "id": "chatcmpl-8Da2OrDsn5wlK3tt85Lw0qmx9Z1wR",
#   "object": "chat.completion",
#   "created": 1698247484,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "Putrescine is a small organic compound that is naturally produced in living organisms as a result of the breakdown of amino acids. Zinc, on the other hand, is a chemical element that is essential for various biological processes in the body.\n\nThere is no direct association between putrescine and zinc. However, zinc plays a crucial role in the metabolism of amino acids, including putrescine. Zinc is required for the activity of enzymes involved in the synthesis and degradation of amino acids, including those involved in the breakdown of putrescine.\n\nAdditionally, zinc is known to have a regulatory effect on the levels of putrescine in the body. It has been observed that zinc deficiency can lead to an increase in putrescine levels, while zinc supplementation can help normalize putrescine levels.\n\nOverall, while there is no direct association between putrescine and zinc, zinc plays a significant role in the metabolism and regulation of putrescine levels in the body."
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 19,
#     "completion_tokens": 200,
#     "total_tokens": 219
#   }
# }

# %%
query3 = "What is the association between calcium and zinT?"
qa.run(query3, callbacks=[handler])
# Out:
# > Entering new RetrievalQA chain...
#
# 	>> Generating list of revelant terms
# 	Identified Terms:
# 	['calcium', 'zinc']
#
# 	>> Searching for related graph nodes
# 	Identified Nodes:
# 	[{'term': 'calcium', 'matches': [{'node': {'original_entity_types': ['Chemical'], 'eid': 'D002118', 'obsolete': 0, 'name': 'Calcium', 'mesh_id': 'D002118', 'data_source': 'MeSH'}, 'similarity': 0.8571428571428571, 'node_id': 83342363}, {'node': {'original_entity_types': ['Chemical'], 'eid': '29320', 'inchi_key': 'OYPRJOBELJOOCE-UHFFFAOYSA-N', 'name': 'calcium(0)', 'data_source': 'ChEBI'}, 'similarity': 0.7, 'node_id': 11346629}, {'node': {'original_entity_types': ['Chemical'], 'eid': '22984', 'inchi_key': 'OYPRJOBELJOOCE-UHFFFAOYSA-N', 'name': 'calcium atom', 'data_source': 'ChEBI'}, 'similarity': 0.5833333333333334, 'node_id': 11332843}, {'node': {'original_entity_types': ['Chemical'], 'eid': '22984', 'inchi_key': 'OYPRJOBELJOOCE-UHFFFAOYSA-N', 'name': 'calcium atom', 'data_source': 'ChEBI'}, 'similarity': 0.5833333333333334, 'node_id': 11332843}, {'node': {'original_entity_types': ['Chemical'], 'eid': '22984', 'inchi_key': 'OYPRJOBELJOOCE-UHFFFAOYSA-N', 'name': 'calcium atom', 'data_source': 'ChEBI'}, 'similarity': 0.5833333333333334, 'node_id': 11332843}]}, {'term': 'zinc', 'matches': [{'node': {'original_entity_types': ['Chemical'], 'eid': 'D015032', 'mesh_id': 'D015032', 'obsolete': 0, 'name': 'Zinc', 'data_source': 'MeSH'}, 'similarity': 0.75, 'node_id': 83286921}, {'node': {'original_entity_types': ['Chemical'], 'eid': '30185', 'inchi_key': 'HCHKCACWOHOZIP-UHFFFAOYSA-N', 'name': 'zinc(0)', 'data_source': 'ChEBI'}, 'similarity': 0.5714285714285714, 'node_id': 11397922}]}]
#
# 	>> Searching for related graph relationships
#
# 	Identified Relationships:
# 	[]
#
#
#
# > Entering new StuffDocumentsChain chain...
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# System: Use the following pieces of context to answer the users question.
# If you don't know the answer, just say that you don't know, don't try to make up an answer.
# ----------------
# calcium:
# - matches:
#   - eid: D002118
#     name: Calcium
#     similarity: 0.8571428571428571
#   - eid: '29320'
#     name: calcium(0)
#     similarity: 0.7
#   - eid: '22984'
#     name: calcium atom
#     similarity: 0.5833333333333334
#   - eid: '22984'
#     name: calcium atom
#     similarity: 0.5833333333333334
#   - eid: '22984'
#     name: calcium atom
#     similarity: 0.5833333333333334
#
#
# zinc:
# - matches:
#   - eid: D015032
#     name: Zinc
#     similarity: 0.75
#   - eid: '30185'
#     name: zinc(0)
#     similarity: 0.5714285714285714
#
# Human: What is the association between calcium and zinT?
#
# > Finished chain.
#
# > Finished chain.
#
# > Finished chain.
# 'There is no specific association mentioned between calcium and zinc in the provided context.'

# %%
chatGPTQA(query3)
# Out:
# <OpenAIObject chat.completion id=chatcmpl-8Da2WDpJEP3aGkDc45I4OoGQWZxaH at 0x7f593795f110> JSON: {
#   "id": "chatcmpl-8Da2WDpJEP3aGkDc45I4OoGQWZxaH",
#   "object": "chat.completion",
#   "created": 1698247492,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "There is no direct association between calcium and zinT. Calcium is a mineral that plays a crucial role in various bodily functions, including bone health, muscle contraction, nerve transmission, and blood clotting. It is primarily found in dairy products, leafy greens, and fortified foods.\n\nOn the other hand, zinT is not a recognized term or mineral. It is possible that you may be referring to zinc, which is another essential mineral involved in numerous physiological processes. Zinc is important for immune function, wound healing, DNA synthesis, and cell division. It is found in foods like meat, shellfish, legumes, and nuts.\n\nWhile both calcium and zinc are essential minerals for the body, they have distinct roles and functions and do not have a direct association with each other."
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 18,
#     "completion_tokens": 158,
#     "total_tokens": 176
#   }
# }

# %% [markdown]
# ## Check background noise

# %%
qa.run("What is the relationship between INHBA and MTMR4?", callbacks=[handler])
# Out:
# > Entering new RetrievalQA chain...
#
# 	>> Generating list of revelant terms
# 	Identified Terms:
# 	['INHBA', 'MTMR4']
#
# 	>> Searching for related graph nodes
# 	Identified Nodes:
# 	[{'term': 'INHBA', 'matches': [{'node': {'original_entity_types': ['Gene'], 'eid': '121028933', 'full_name': 'inhibin subunit beta A', 'name': 'INHBA', 'locus_tag': '', 'tax_id': '1608482', 'data_source': 'NCBI Gene'}, 'similarity': 1.0, 'node_id': 97704812}, {'node': {'original_entity_types': ['Gene'], 'eid': '119698030', 'full_name': 'inhibin subunit beta A', 'name': 'INHBA', 'locus_tag': '', 'tax_id': '1094192', 'data_source': 'NCBI Gene'}, 'similarity': 1.0, 'node_id': 97138396}, {'node': {'original_entity_types': ['Gene'], 'eid': '121333580', 'full_name': 'inhibin subunit beta A', 'name': 'INHBA', 'locus_tag': '', 'data_source': 'NCBI Gene', 'tax_id': '356909'}, 'similarity': 1.0, 'node_id': 96113143}, {'node': {'original_entity_types': ['Gene'], 'eid': '120398268', 'full_name': 'inhibin subunit beta A', 'name': 'INHBA', 'locus_tag': '', 'data_source': 'NCBI Gene', 'tax_id': '260615'}, 'similarity': 1.0, 'node_id': 95794332}, {'node': {'original_entity_types': ['Gene'], 'eid': '121353070', 'full_name': 'inhibin subunit beta A', 'name': 'INHBA', 'locus_tag': '', 'data_source': 'NCBI Gene', 'tax_id': '221976'}, 'similarity': 1.0, 'node_id': 95909369}, {'node': {'original_entity_types': ['Gene'], 'eid': '118989268', 'full_name': 'inhibin subunit beta A', 'name': 'INHBA', 'locus_tag': '', 'data_source': 'NCBI Gene', 'tax_id': '192404'}, 'similarity': 1.0, 'node_id': 95664639}, {'node': {'original_entity_types': ['Gene'], 'eid': '118929076', 'full_name': 'inhibin subunit beta A', 'name': 'INHBA', 'locus_tag': '', 'data_source': 'NCBI Gene', 'tax_id': '143292'}, 'similarity': 1.0, 'node_id': 95382500}, {'node': {'original_entity_types': ['Gene'], 'eid': '121087860', 'full_name': 'inhibin subunit beta A', 'name': 'INHBA', 'locus_tag': '', 'data_source': 'NCBI Gene', 'tax_id': '148594'}, 'similarity': 1.0, 'node_id': 95422705}, {'node': {'original_entity_types': ['Gene'], 'eid': '120591502', 'full_name': 'inhibin subunit beta A', 'name': 'INHBA', 'locus_tag': '', 'data_source': 'NCBI Gene', 'tax_id': '143291'}, 'similarity': 1.0, 'node_id': 95314115}, {'node': {'original_entity_types': ['Gene'], 'eid': '121145766', 'full_name': 'inhibin subunit beta A', 'name': 'INHBA', 'locus_tag': '', 'data_source': 'NCBI Gene', 'tax_id': '130825'}, 'similarity': 1.0, 'node_id': 95152385}]}, {'term': 'MTMR4', 'matches': [{'node': {'original_entity_types': ['Gene'], 'eid': '121044716', 'full_name': 'myotubularin related protein 4', 'name': 'MTMR4', 'locus_tag': '', 'data_source': 'NCBI Gene', 'tax_id': '1608482'}, 'similarity': 1.0, 'node_id': 97753512}, {'node': {'original_entity_types': ['Gene'], 'eid': '119709734', 'full_name': 'myotubularin related protein 4', 'name': 'MTMR4', 'locus_tag': '', 'data_source': 'NCBI Gene', 'tax_id': '1094192'}, 'similarity': 1.0, 'node_id': 97032251}, {'node': {'original_entity_types': ['Gene'], 'eid': '121346864', 'full_name': 'myotubularin related protein 4', 'name': 'MTMR4', 'locus_tag': '', 'tax_id': '356909', 'data_source': 'NCBI Gene'}, 'similarity': 1.0, 'node_id': 96167090}, {'node': {'original_entity_types': ['Gene'], 'eid': '120387235', 'full_name': 'myotubularin related protein 4', 'name': 'MTMR4', 'locus_tag': '', 'tax_id': '260615', 'data_source': 'NCBI Gene'}, 'similarity': 1.0, 'node_id': 95916363}, {'node': {'original_entity_types': ['Gene'], 'eid': '121362956', 'full_name': 'myotubularin related protein 4', 'name': 'MTMR4', 'locus_tag': '', 'tax_id': '221976', 'data_source': 'NCBI Gene'}, 'similarity': 1.0, 'node_id': 95795994}, {'node': {'original_entity_types': ['Gene'], 'eid': '119003726', 'full_name': 'myotubularin related protein 4', 'name': 'MTMR4', 'locus_tag': '', 'tax_id': '192404', 'data_source': 'NCBI Gene'}, 'similarity': 1.0, 'node_id': 95612971}, {'node': {'original_entity_types': ['Gene'], 'eid': '121096376', 'full_name': 'myotubularin related protein 4', 'name': 'MTMR4', 'locus_tag': '', 'tax_id': '148594', 'data_source': 'NCBI Gene'}, 'similarity': 1.0, 'node_id': 95481805},  ...
#
# 	>> Searching for related graph relationships
#
# 	Identified Relationships:
# 	[]
#
#
#
# > Entering new StuffDocumentsChain chain...
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# System: Use the following pieces of context to answer the users question.
# If you don't know the answer, just say that you don't know, don't try to make up an answer.
# ----------------
# INHBA:
# - matches:
#   - eid: '121028933'
#     name: INHBA
#     similarity: 1.0
#   - eid: '119698030'
#     name: INHBA
#     similarity: 1.0
#   - eid: '121333580'
#     name: INHBA
#     similarity: 1.0
#   - eid: '120398268'
#     name: INHBA
#     similarity: 1.0
#   - eid: '121353070'
#     name: INHBA
#     similarity: 1.0
#   - eid: '118989268'
#     name: INHBA
#     similarity: 1.0
#   - eid: '118929076'
#     name: INHBA
#     similarity: 1.0
#   - eid: '121087860'
#     name: INHBA
#     similarity: 1.0
#   - eid: '120591502'
#     name: INHBA
#     similarity: 1.0
#   - eid: '121145766'
#     name: INHBA
#     similarity: 1.0
#
#
# MTMR4:
# - matches:
#   - eid: '121044716'
#     name: MTMR4
#     similarity: 1.0
#   - eid: '119709734'
#     name: MTMR4
#     similarity: 1.0
#   - eid: '121346864'
#     name: MTMR4
#     similarity: 1.0
#   - eid: '120387235'
#     name: MTMR4
#     similarity: 1.0
#   - eid: '121362956'
#     name: MTMR4
#     similarity: 1.0
#   - eid: '119003726'
#     name: MTMR4
#     similarity: 1.0
#   - eid: '121096376'
#     name: MTMR4
#     similarity: 1.0
#   - eid: '118909410'
#     name: MTMR4
#     similarity: 1.0
#   - eid: '120620810'
#     name: MTMR4
#     similarity: 1.0
#   - eid: '121169671'
#     name: MTMR4
#     similarity: 1.0
#
# Human: What is the relationship between INHBA and MTMR4?
#
# > Finished chain.
#
# > Finished chain.
#
# > Finished chain.
# 'Based on the provided information, there is no specific relationship mentioned between INHBA and MTMR4.'

# %% [markdown]
# ## Check different qa stuffing techniques

# %%
from langchain.chains import RetrievalQA

# %%
qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="map_reduce",
    retriever=retriever,
    verbose=True,
    callbacks=[handler]
)
qa
# Out:
# RetrievalQA(memory=None, callbacks=[<langchain.callbacks.stdout.StdOutCallbackHandler object at 0x7f5937940810>], callback_manager=None, verbose=True, tags=None, metadata=None, combine_documents_chain=MapReduceDocumentsChain(memory=None, callbacks=None, callback_manager=None, verbose=False, tags=None, metadata=None, input_key='input_documents', output_key='output_text', llm_chain=LLMChain(memory=None, callbacks=None, callback_manager=None, verbose=False, tags=None, metadata=None, prompt=ChatPromptTemplate(input_variables=['context', 'question'], output_parser=None, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context'], output_parser=None, partial_variables={}, template='Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\n______________________\n{context}', template_format='f-string', validate_template=True), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['question'], output_parser=None, partial_variables={}, template='{question}', template_format='f-string', validate_template=True), additional_kwargs={})]), llm=ChatOpenAI(cache=None, verbose=True, callbacks=None, callback_manager=None, tags=None, metadata=None, client=<class 'openai.api_resources.chat_completion.ChatCompletion'>, model_name='gpt-3.5-turbo', temperature=0.0, model_kwargs={}, openai_api_key='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', openai_api_base='', openai_organization='', openai_proxy='', request_timeout=None, max_retries=6, streaming=False, n=1, max_tokens=None, tiktoken_model_name=None), output_key='text', output_parser=StrOutputParser(), return_final_only=True, llm_kwargs={}), reduce_documents_chain=ReduceDocumentsChain(memory=None, callbacks=None, callback_manager=None, verbose=False, tags=None, metadata=None, input_key='input_documents', output_key='output_text', combine_documents_chain=StuffDocumentsChain(memory=None, callbacks=None, callback_manager=None, verbose=False, tags=None, metadata=None, input_key='input_documents', output_key='output_text', llm_chain=LLMChain(memory=None, callbacks=None, callback_manager=None, verbose=False, tags=None, metadata=None, prompt=ChatPromptTemplate(input_variables=['question', 'summaries'], output_parser=None, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['summaries'], output_parser=None, partial_variables={}, template="Given the following extracted parts of a long document and a question, create a final answer. \nIf you don't know the answer, just say that you don't know. Don't try to make up an answer.\n______________________\n{summaries}", template_format='f-string', validate_template=True), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['question'], output_parser=None, partial_variables={}, template='{question}', template_format='f-string', validate_template=True), additional_kwargs={})]), llm=ChatOpenAI(cache=None, verbose=True, callbacks=None, callback_manager=None, tags=None, metadata=None, client=<class 'openai.api_resources.chat_completion.ChatCompletion'>, model_name='gpt-3.5-turbo', temperature=0.0, model_kwargs={}, openai_api_key='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', openai_api_base='', openai_organization='', openai_proxy='', request_timeout=None, max_retries=6, streaming=False, n=1, max_tokens=None, tiktoken_model_name=None), output_key='text', output_parser=StrOutputParser(), return_final_only=True, llm_kwargs={}), document_prompt=PromptTemplate(input_variables=['page_content'], output_parser=None, partial_variables={}, template='{page_content}', template_format='f-string', validate_template=True), document_variable_name='summaries', document_separator='\n\n'), collapse_documents_chain=None, token_max=3000), document_variable_name='context', return_intermediate_steps=False), input_key='query ...

# %%
qa.run(query, callbacks=[handler])
# Out:
# > Entering new RetrievalQA chain...
#
# 	>> Generating list of revelant terms
# 	Identified Terms:
# 	['Zn2+', 'glycolate']
#
# 	>> Searching for related graph nodes
# 	Identified Nodes:
# 	[{'term': 'Zn2+', 'matches': [{'node': {'original_entity_types': ['Compound'], 'eid': 'ZN+2', 'inchi': 'InChI=1S/Zn/q+2', 'abbrev_name': '', 'smiles': '[Zn+2]', 'entityType': 'Chemical', 'displayName': 'Zn2+', 'inchi_key': 'PTFCDOFLOPIGGS-UHFFFAOYSA-N', 'name': 'Zn2+', 'biocyc_id': 'ZN+2', 'data_source': 'BioCyc'}, 'similarity': 1.0, 'node_id': 3703030}]}, {'term': 'glycolate', 'matches': [{'node': {'original_entity_types': ['Compound'], 'eid': 'GLYCOLLATE', 'inchi': 'InChI=1S/C2H4O3/c3-1-2(4)5/h3H,1H2,(H,4,5)/p-1', 'abbrev_name': '', 'smiles': 'C(C(=O)[O-])O', 'entityType': 'Chemical', 'displayName': 'glycolate', 'inchi_key': 'AEMRFAOFKBGASW-UHFFFAOYSA-M', 'name': 'glycolate', 'biocyc_id': 'GLYCOLLATE', 'data_source': 'BioCyc'}, 'similarity': 1.0, 'node_id': 3703369}, {'node': {'original_entity_types': ['Chemical'], 'eid': '29805', 'inchi_key': 'AEMRFAOFKBGASW-UHFFFAOYSA-M', 'name': 'glycolate', 'data_source': 'ChEBI', 'alt_id': 'CHEBI:14348|CHEBI:24388'}, 'similarity': 1.0, 'node_id': 11166676}, {'node': {'original_entity_types': ['Chemical'], 'eid': 'C031149', 'obsolete': 0, 'name': 'glycolic acid', 'mesh_id': 'C031149', 'data_source': 'MeSH'}, 'similarity': 0.5384615384615384, 'node_id': 9967120}]}]
#
# 	>> Searching for related graph relationships
#
# 	Identified Relationships:
# 	[{'path': [{'original_entity_types': ['Compound'], 'eid': 'ZN+2', 'inchi': 'InChI=1S/Zn/q+2', 'abbrev_name': '', 'smiles': '[Zn+2]', 'entityType': 'Chemical', 'displayName': 'Zn2+', 'inchi_key': 'PTFCDOFLOPIGGS-UHFFFAOYSA-N', 'name': 'Zn2+', 'biocyc_id': 'ZN+2', 'data_source': 'BioCyc'}, 'REGULATES', {'mode': '-', 'eid': 'REG0-12395', 'displayName': 'Regulation-of-Enzyme-Activity (-)', 'type': 'Regulation-of-Enzyme-Activity', 'biocyc_id': 'REG0-12395'}, 'REGULATES', {'eid': 'ENZRXN0-8126', 'genes': 'yajL', 'displayName': 'glyoxalase III', 'name': 'glyoxalase III', 'description': 'complex of protein/nucleic acid deglycase 3 YajL, catalyzes reaction: H2O + glyoxal --> H+ + glycolate', 'biocyc_id': 'ENZRXN0-8126'}, 'CATALYZES', {'eid': 'RXN0-7173', 'entityType': 'Reaction', 'displayName': 'EC-4.2.1', 'ec_number': 'EC-4.2.1', 'name': 'RXN0-7173', 'description': 'Hydro-lyases: H2O + glyoxal --> H+ + glycolate', 'detail': 'H2O + glyoxal => H+ + glycolate', 'biocyc_id': 'RXN0-7173'}, 'PRODUCES', {'original_entity_types': ['Compound'], 'eid': 'GLYCOLLATE', 'inchi': 'InChI=1S/C2H4O3/c3-1-2(4)5/h3H,1H2,(H,4,5)/p-1', 'abbrev_name': '', 'smiles': 'C(C(=O)[O-])O', 'entityType': 'Chemical', 'displayName': 'glycolate', 'inchi_key': 'AEMRFAOFKBGASW-UHFFFAOYSA-M', 'name': 'glycolate', 'biocyc_id': 'GLYCOLLATE', 'data_source': 'BioCyc'}]}, {'path': [{'original_entity_types': ['Compound'], 'eid': 'ZN+2', 'inchi': 'InChI=1S/Zn/q+2', 'abbrev_name': '', 'smiles': '[Zn+2]', 'entityType': 'Chemical', 'displayName': 'Zn2+', 'inchi_key': 'PTFCDOFLOPIGGS-UHFFFAOYSA-N', 'name': 'Zn2+', 'biocyc_id': 'ZN+2', 'data_source': 'BioCyc'}, 'REGULATES', {'mode': '-', 'eid': 'REG0-9208', 'displayName': 'Regulation-of-Enzyme-Activity (-)', 'type': 'Regulation-of-Enzyme-Activity', 'biocyc_id': 'REG0-9208'}, 'REGULATES', {'eid': 'GLYCOLALD-DEHYDROG-ENZRXN', 'genes': 'aldA', 'displayName': 'glycolaldehyde dehydrogenase', 'name': 'glycolaldehyde dehydrogenase', 'description': 'complex of aldehyde dehydrogenase A AldA, catalyzes reaction: glycolaldehyde + NAD+ + H2O --> glycolate + NADH + H+', 'biocyc_id': 'GLYCOLALD-DEHYDROG-ENZRXN'}, 'CATALYZES', {'eid': 'GLYCOLALD-DEHYDROG-RXN', 'entityType': 'Reaction', 'ec_number': 'EC-1.2.1.21', 'displayName': 'EC-1.2.1.21', 'name': '', 'description': 'Glycolaldehyde dehydrogenase: glycolaldehyde + NAD+ + H2O --> glycolate + NADH + H+', 'location': '', 'detail': 'glycolaldehyde + NAD+ + H2O => glycolate + NADH + H+', 'biocyc_id': 'GLYCOLALD-DEHYDROG-RXN', 'data_source': 'BioCyc', 'direction': ''}, 'PRODUCES', {'original_entity_types': ['Compound'], 'eid': 'GLYCOLLATE', 'inchi': 'InChI=1S/C2H4O3/c3-1-2(4)5/h3H,1H2,(H,4,5)/p-1', 'abbrev_name': '', 'smiles': 'C(C(=O)[O-])O', 'entityType': 'Chemical', 'displayName': 'glycolate', 'inchi_key': 'AEMRFAOFKBGASW-UHFFFAOYSA-M', 'name': 'glycolate', 'biocyc_id': 'GLYCOLLATE', 'data_source': 'BioCyc'}]}, {'path': [{'original_entity_types': ['Compound'], 'eid': 'ZN+2', 'inchi': 'InChI=1S/Zn/q+2', 'abbrev_name': '', 'smiles': '[Zn+2]', 'entityType': 'Chemical', 'displayName': 'Zn2+', 'inchi_key': 'PTFCDOFLOPIGGS-UHFFFAOYSA-N', 'name': 'Zn2+', 'biocyc_id': 'ZN+2', 'data_source': 'BioCyc'}, 'REGULATES', {'mode': '-', 'eid': 'REG0-10246', 'displayName': 'Regulation-of-Enzyme-Activity (-)', 'type': 'Regulation-of-Enzyme-Activity', 'biocyc_id': 'REG0-10246'}, 'REGULATES', {'eid': 'GLYCOLATEDEHYDRO-ENZRXN', 'genes': 'glcD, glcE, glcF', 'displayName': 'glycolate dehydrogenase', 'name': 'glycolate dehydrogenase', 'description': 'complex of glycolate dehydrogenase, putative FAD-binding subunit GlcE, glycolate dehydrogenase, putative FAD-linked subunit GlcD, glycolate dehydrogenase, putative iron-sulfur subunit GlcF, catalyzes reaction: glycolate + oxidized unknown electron carrier --> glyoxylate + reduced unknown two electron carrier', 'biocyc_id': 'GLYCOLATEDEHYDRO-ENZRXN'}, 'CATALYZES', {'eid': 'GLYCOLATEDEHYDRO-RXN', 'entityType': 'Reaction', 'ec_number': 'EC-1.1.99.14', 'displayName': 'EC-1.1.99.14 ...
#
#
#
# > Entering new MapReduceDocumentsChain chain...
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# System: Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# ______________________
# Zn2+:
# - matches:
#   - eid: ZN+2
#     name: Zn2+
#     similarity: 1.0
#
# Human: What is the relationship between Zn2+ and glycolate?
# Prompt after formatting:
# System: Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# ______________________
# glycolate:
# - matches:
#   - eid: GLYCOLLATE
#     name: glycolate
#     similarity: 1.0
#   - eid: '29805'
#     name: glycolate
#     similarity: 1.0
#   - eid: C031149
#     name: glycolic acid
#     similarity: 0.5384615384615384
#
# Human: What is the relationship between Zn2+ and glycolate?
# Prompt after formatting:
# System: Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# ______________________
# relationship:
#   nodes:
#     ENZRXN0-8126:
#       description: 'complex of protein/nucleic acid deglycase 3 YajL, catalyzes reaction:
#         H2O + glyoxal --> H+ + glycolate'
#       name: glyoxalase III
#       type: null
#     GLYCOLLATE:
#       description: null
#       name: glycolate
#       type: Chemical
#     REG0-12395:
#       description: null
#       name: Regulation-of-Enzyme-Activity (-)
#       type: Regulation-of-Enzyme-Activity
#     RXN0-7173:
#       description: 'Hydro-lyases: H2O + glyoxal --> H+ + glycolate'
#       name: EC-4.2.1
#       type: Reaction
#     ZN+2:
#       description: null
#       name: Zn2+
#       type: Chemical
#   path: ZN+2 - REGULATES - REG0-12395 - REGULATES - ENZRXN0-8126 - CATALYZES - RXN0-7173
#     - PRODUCES - GLYCOLLATE
#
# Human: What is the relationship between Zn2+ and glycolate?
# Prompt after formatting:
# System: Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# ______________________
# relationship:
#   nodes:
#     GLYCOLALD-DEHYDROG-ENZRXN:
#       description: 'complex of aldehyde dehydrogenase A AldA, catalyzes reaction:
#         glycolaldehyde + NAD+ + H2O --> glycolate + NADH + H+'
#       name: glycolaldehyde dehydrogenase
#       type: null
#     GLYCOLALD-DEHYDROG-RXN:
#       description: 'Glycolaldehyde dehydrogenase: glycolaldehyde + NAD+ + H2O -->
#         glycolate + NADH + H+'
#       name: EC-1.2.1.21
#       type: Reaction
#     GLYCOLLATE:
#       description: null
#       name: glycolate
#       type: Chemical
#     REG0-9208:
#       description: null
#       name: Regulation-of-Enzyme-Activity (-)
#       type: Regulation-of-Enzyme-Activity
#     ZN+2:
#       description: null
#       name: Zn2+
#       type: Chemical
#   path: ZN+2 - REGULATES - REG0-9208 - REGULATES - GLYCOLALD-DEHYDROG-ENZRXN - CATALYZES
#     - GLYCOLALD-DEHYDROG-RXN - PRODUCES - GLYCOLLATE
#
# Human: What is the relationship between Zn2+ and glycolate?
# Prompt after formatting:
# System: Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# ______________________
# relationship:
#   nodes:
#     GLYCOLATEDEHYDRO-ENZRXN:
#       description: 'complex of glycolate dehydrogenase, putative FAD-binding subunit
#         GlcE, glycolate dehydrogenase, putative FAD-linked subunit GlcD, glycolate
#         dehydrogenase, putative iron-sulfur subunit GlcF, catalyzes reaction: glycolate
#         + oxidized unknown electron carrier --> glyoxylate + reduced unknown two electron
#         carrier'
#       name: glycolate dehydrogenase
#       type: null
#     GLYCOLATEDEHYDRO-RXN:
#       description: 'Glycolate dehydrogenase: glycolate + oxidized unknown electron
#         carrier --> glyoxylate + reduced unknown two electron carrier'
#       name: EC-1.1.99.14
#       type: Reaction
#     GLYCOLLATE:
#       description: null
#       name: glycolate
#       type: Chemical
#     REG0-10246:
#       description: null
#       name: Regulation-of-Enzyme-Activity (-)
#       type: Regulation-of-Enzyme-Activity
#     ZN+2:
#       description: null
#       name: Zn2+
#       type: Chemical
#   path: ZN+2 - REGULATES - REG0-10246 - REGULATES - GLYCOLATEDEHYDRO-ENZRXN - CATALYZES
#     - GLYCOLATEDEHYDRO-RXN - CONSUMED_BY - GLYCOLLATE
#
# Human: What is the relationship between Zn2+ and glycolate?
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# System: Given the following extracted parts of a long document and a question, create a final answer.
# If you don't know the answer, just say that you don't know. Don't try to make up an answer.
# ______________________
# There is no information provided in the given portion of the document about the relationship between Zn2+ and glycolate.
#
# There is no information provided in the given portion of the document about the relationship between Zn2+ and glycolate.
#
# The relationship between Zn2+ and glycolate is that Zn2+ regulates the production of glycolate.
#
# The relationship between Zn2+ and glycolate is as follows:
#
# ZN+2 - REGULATES - REG0-9208 - REGULATES - GLYCOLALD-DEHYDROG-ENZRXN - CATALYZES - GLYCOLALD-DEHYDROG-RXN - PRODUCES - GLYCOLLATE
#
# The relationship between Zn2+ and glycolate is as follows:
#
# ZN+2 - REGULATES - REG0-10246 - REGULATES - GLYCOLATEDEHYDRO-ENZRXN - CATALYZES - GLYCOLATEDEHYDRO-RXN - CONSUMED_BY - GLYCOLLATE
# Human: What is the relationship between Zn2+ and glycolate?
#
# > Finished chain.
#
# > Finished chain.
#
# > Finished chain.
# 'There is no information provided in the given portion of the document about the relationship between Zn2+ and glycolate.'

# %%
qa.run("What is the relationship between INHBA and MTMR4?", callbacks=[handler])
# Out:
# > Entering new RetrievalQA chain...
#
# 	>> Generating list of revelant terms
# 	Identified Terms:
# 	['INHBA', 'MTMR4']
#
# 	>> Searching for related graph nodes
# 	Identified Nodes:
# 	[{'term': 'INHBA', 'matches': [{'node': {'original_entity_types': ['Gene'], 'eid': '121028933', 'full_name': 'inhibin subunit beta A', 'name': 'INHBA', 'locus_tag': '', 'tax_id': '1608482', 'data_source': 'NCBI Gene'}, 'similarity': 1.0, 'node_id': 97704812}, {'node': {'original_entity_types': ['Gene'], 'eid': '119698030', 'full_name': 'inhibin subunit beta A', 'name': 'INHBA', 'locus_tag': '', 'tax_id': '1094192', 'data_source': 'NCBI Gene'}, 'similarity': 1.0, 'node_id': 97138396}, {'node': {'original_entity_types': ['Gene'], 'eid': '121333580', 'full_name': 'inhibin subunit beta A', 'name': 'INHBA', 'locus_tag': '', 'data_source': 'NCBI Gene', 'tax_id': '356909'}, 'similarity': 1.0, 'node_id': 96113143}, {'node': {'original_entity_types': ['Gene'], 'eid': '120398268', 'full_name': 'inhibin subunit beta A', 'name': 'INHBA', 'locus_tag': '', 'data_source': 'NCBI Gene', 'tax_id': '260615'}, 'similarity': 1.0, 'node_id': 95794332}, {'node': {'original_entity_types': ['Gene'], 'eid': '121353070', 'full_name': 'inhibin subunit beta A', 'name': 'INHBA', 'locus_tag': '', 'data_source': 'NCBI Gene', 'tax_id': '221976'}, 'similarity': 1.0, 'node_id': 95909369}, {'node': {'original_entity_types': ['Gene'], 'eid': '118989268', 'full_name': 'inhibin subunit beta A', 'name': 'INHBA', 'locus_tag': '', 'data_source': 'NCBI Gene', 'tax_id': '192404'}, 'similarity': 1.0, 'node_id': 95664639}, {'node': {'original_entity_types': ['Gene'], 'eid': '118929076', 'full_name': 'inhibin subunit beta A', 'name': 'INHBA', 'locus_tag': '', 'data_source': 'NCBI Gene', 'tax_id': '143292'}, 'similarity': 1.0, 'node_id': 95382500}, {'node': {'original_entity_types': ['Gene'], 'eid': '121087860', 'full_name': 'inhibin subunit beta A', 'name': 'INHBA', 'locus_tag': '', 'data_source': 'NCBI Gene', 'tax_id': '148594'}, 'similarity': 1.0, 'node_id': 95422705}, {'node': {'original_entity_types': ['Gene'], 'eid': '120591502', 'full_name': 'inhibin subunit beta A', 'name': 'INHBA', 'locus_tag': '', 'data_source': 'NCBI Gene', 'tax_id': '143291'}, 'similarity': 1.0, 'node_id': 95314115}, {'node': {'original_entity_types': ['Gene'], 'eid': '121145766', 'full_name': 'inhibin subunit beta A', 'name': 'INHBA', 'locus_tag': '', 'data_source': 'NCBI Gene', 'tax_id': '130825'}, 'similarity': 1.0, 'node_id': 95152385}]}, {'term': 'MTMR4', 'matches': [{'node': {'original_entity_types': ['Gene'], 'eid': '121044716', 'full_name': 'myotubularin related protein 4', 'name': 'MTMR4', 'locus_tag': '', 'data_source': 'NCBI Gene', 'tax_id': '1608482'}, 'similarity': 1.0, 'node_id': 97753512}, {'node': {'original_entity_types': ['Gene'], 'eid': '119709734', 'full_name': 'myotubularin related protein 4', 'name': 'MTMR4', 'locus_tag': '', 'data_source': 'NCBI Gene', 'tax_id': '1094192'}, 'similarity': 1.0, 'node_id': 97032251}, {'node': {'original_entity_types': ['Gene'], 'eid': '121346864', 'full_name': 'myotubularin related protein 4', 'name': 'MTMR4', 'locus_tag': '', 'tax_id': '356909', 'data_source': 'NCBI Gene'}, 'similarity': 1.0, 'node_id': 96167090}, {'node': {'original_entity_types': ['Gene'], 'eid': '120387235', 'full_name': 'myotubularin related protein 4', 'name': 'MTMR4', 'locus_tag': '', 'tax_id': '260615', 'data_source': 'NCBI Gene'}, 'similarity': 1.0, 'node_id': 95916363}, {'node': {'original_entity_types': ['Gene'], 'eid': '121362956', 'full_name': 'myotubularin related protein 4', 'name': 'MTMR4', 'locus_tag': '', 'tax_id': '221976', 'data_source': 'NCBI Gene'}, 'similarity': 1.0, 'node_id': 95795994}, {'node': {'original_entity_types': ['Gene'], 'eid': '119003726', 'full_name': 'myotubularin related protein 4', 'name': 'MTMR4', 'locus_tag': '', 'tax_id': '192404', 'data_source': 'NCBI Gene'}, 'similarity': 1.0, 'node_id': 95612971}, {'node': {'original_entity_types': ['Gene'], 'eid': '121096376', 'full_name': 'myotubularin related protein 4', 'name': 'MTMR4', 'locus_tag': '', 'tax_id': '148594', 'data_source': 'NCBI Gene'}, 'similarity': 1.0, 'node_id': 95481805},  ...
#
# 	>> Searching for related graph relationships
#
# 	Identified Relationships:
# 	[]
#
#
#
# > Entering new MapReduceDocumentsChain chain...
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# System: Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# ______________________
# INHBA:
# - matches:
#   - eid: '121028933'
#     name: INHBA
#     similarity: 1.0
#   - eid: '119698030'
#     name: INHBA
#     similarity: 1.0
#   - eid: '121333580'
#     name: INHBA
#     similarity: 1.0
#   - eid: '120398268'
#     name: INHBA
#     similarity: 1.0
#   - eid: '121353070'
#     name: INHBA
#     similarity: 1.0
#   - eid: '118989268'
#     name: INHBA
#     similarity: 1.0
#   - eid: '118929076'
#     name: INHBA
#     similarity: 1.0
#   - eid: '121087860'
#     name: INHBA
#     similarity: 1.0
#   - eid: '120591502'
#     name: INHBA
#     similarity: 1.0
#   - eid: '121145766'
#     name: INHBA
#     similarity: 1.0
#
# Human: What is the relationship between INHBA and MTMR4?
# Prompt after formatting:
# System: Use the following portion of a long document to see if any of the text is relevant to answer the question.
# Return any relevant text verbatim.
# ______________________
# MTMR4:
# - matches:
#   - eid: '121044716'
#     name: MTMR4
#     similarity: 1.0
#   - eid: '119709734'
#     name: MTMR4
#     similarity: 1.0
#   - eid: '121346864'
#     name: MTMR4
#     similarity: 1.0
#   - eid: '120387235'
#     name: MTMR4
#     similarity: 1.0
#   - eid: '121362956'
#     name: MTMR4
#     similarity: 1.0
#   - eid: '119003726'
#     name: MTMR4
#     similarity: 1.0
#   - eid: '121096376'
#     name: MTMR4
#     similarity: 1.0
#   - eid: '118909410'
#     name: MTMR4
#     similarity: 1.0
#   - eid: '120620810'
#     name: MTMR4
#     similarity: 1.0
#   - eid: '121169671'
#     name: MTMR4
#     similarity: 1.0
#
# Human: What is the relationship between INHBA and MTMR4?
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# System: Given the following extracted parts of a long document and a question, create a final answer.
# If you don't know the answer, just say that you don't know. Don't try to make up an answer.
# ______________________
# There is no information provided in the given portion of the document about the relationship between INHBA and MTMR4.
#
# There is no information provided in the given portion of the document about the relationship between INHBA and MTMR4.
# Human: What is the relationship between INHBA and MTMR4?
#
# > Finished chain.
#
# > Finished chain.
#
# > Finished chain.
# 'There is no information provided in the given portion of the document about the relationship between INHBA and MTMR4.'
