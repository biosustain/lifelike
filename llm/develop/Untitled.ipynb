"2009-02-01",	
"2009-01-01",	
"2008-12-01",	
"2008-11-01",	
"2008-10-01",	
"2008-09-01",	
"2008-08-01",	
"2008-07-01",	
"2008-06-01",	
"2008-05-01",	
"2008-04-01",	
"2008-03-01",	
"2008-02-01",	
"2008-01-01",	
"2007-12-01",	
"2007-11-01",	
"2007-10-01",	
"2007-09-01",	
"2007-08-01",	
"2007-07-01",	
"2007-06-01",	
"2007-05-01",	
"2007-04-01",	
"2007-03-01",	
"2007-02-01",	
"2007-01-01",	
"2006-12-01",	
"2006-11-01",	
"2006-10-01",	
"2006-09-01",	
"2006-08-01",	
"2006-07-01",	
"2006-06-01",	
"2006-05-01",	
"2006-04-01",	
"2006-03-01",	
"2006-02-01",	
"2006-01-01",	
"2005-12-01",	
"2005-11-01",	
"2005-10-01",	
"2005-09-01",	
"2005-08-01",	
"2005-07-01",	
"2005-06-01",	
"2005-05-01",	
"2005-04-01",	
"2005-03-01",	
"2005-02-01",	
"2005-01-01",	
"2004-12-01",	
"2004-11-01",	
"2004-10-01",	
"2004-09-01",	
"2004-08-01",	
"2004-07-01",	
"2004-06-01",	
"2004-05-01",	
"2004-04-01",	
"2004-03-01"
]

# %%
from llmlib.database import Neo4j

# %%
db = Neo4j().graph()

# %%
from urllib.error import HTTPError

# %%
date_search: for date in dates:
    print(date)
    try:
        with urllib.request.urlopen(f"http://release.geneontology.org/{date}/release_stats/go-ontology-changes.json") as js:
            data = json.load(js)
            for term_group in data["detailed_changes"]["created_terms"].values():
                gos = list(map(lambda go: go["id"][3:], term_group))
                result = db.query("MATCH (n:db_GO) WHERE n.eid in $gos RETURN n LIMIT 1", dict(gos=gos))
                if len(result) > 0:
                    print(f"Match: {date}")
                    break date_search
    except HTTPError as e:
        print(e)
        pass
# Out:
#   Cell In[47], line 1
#     date_search: for date in dates:
#                  ^
# SyntaxError: invalid syntax

# %%
dates.reverse()
for date in dates:
    try:
        with urllib.request.urlopen(f"http://release.geneontology.org/{date}/release_stats/go-ontology-changes.json") as js:
            data = json.load(js)
            for term_group in data["detailed_changes"]["created_terms"].values():
                gos = list(map(lambda go: go["id"][3:], term_group))
                result = db.query("MATCH (n:db_GO) WHERE n.eid in $gos RETURN n LIMIT 1", dict(gos=gos))
                assert len(result) > 0, result
                print(date)
    except HTTPError as e:
        print(e)
        pass
else:
# Out:
# 2004-03-01
# HTTP Error 404: Not Found
# pass
# 2004-04-01
# HTTP Error 404: Not Found
# pass
# 2004-05-01
# HTTP Error 404: Not Found
# pass
# 2004-06-01
# HTTP Error 404: Not Found
# pass
# 2004-07-01
# HTTP Error 404: Not Found
# pass
# 2004-08-01
# HTTP Error 404: Not Found
# pass
# 2004-09-01
# HTTP Error 404: Not Found
# pass
# 2004-10-01
# HTTP Error 404: Not Found
# pass
# 2004-11-01
# HTTP Error 404: Not Found
# pass
# 2004-12-01
# HTTP Error 404: Not Found
# pass
# 2005-01-01
# HTTP Error 404: Not Found
# pass
# 2005-02-01
# HTTP Error 404: Not Found
# pass
# 2005-03-01
# HTTP Error 404: Not Found
# pass
# 2005-04-01
# HTTP Error 404: Not Found
# pass
# 2005-05-01
# HTTP Error 404: Not Found
# pass
# 2005-06-01
# HTTP Error 404: Not Found
# pass
# 2005-07-01
# HTTP Error 404: Not Found
# pass
# 2005-08-01
# HTTP Error 404: Not Found
# pass
# 2005-09-01
# HTTP Error 404: Not Found
# pass
# 2005-10-01
# HTTP Error 404: Not Found
# pass
# 2005-11-01
# ...
